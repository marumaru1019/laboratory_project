# %%
from modules.load import *
from modules.lstm import *
sns.set()
from tensorflow.keras.models import load_model

# %% [markdown]
# 0:テーブル
# 1:椅子
# 2:デニム
# 3:ダンボール
# 4:ペットボトル
# 5:指
# 6:マジックテープ
# 7:スポンジ
# 8:ガムテープ
# 9:タオル

# %% [markdown]
# # データの集計

# %%
#標準化前
def plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure(figsize=(12,4))
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(2.4, 2.8)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")
        
#標準化後
def standard_plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure()
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(-2.0, 2.0)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")

# %%
#学習用データ
df_yubi = load("finger3.csv")
df_table = load("tab3.csv")
df_isu = load("isuisu3.csv")
df_petto = load("petto2.csv")
df_dan = load("cardboard4.csv")
df_denim = load("denideni4.csv")
df_magic= load("magic3.csv")
df_gam = load("gamgam3.csv")
df_sponji = load("smonji5.csv")
df_taoru = load("taoru3.csv")

# %%
#データを纏める用に作製
df_list = [df_table,df_isu,df_denim,df_dan,df_petto,df_yubi,df_magic,df_sponji,df_gam,df_taoru]
data_col = ["table","chair","denim","cardboard" ,"pettobottle","finger","magic tape" ,"sponge","gum tape","taoru"]

# %%
def get_xy(data):
    print("data must have only figure data")
    x = data.iloc[:, 0]
    x = np.arange(0,10000,1)
    y = data.iloc[:, 1]
    y = signal.resample(y,10000)
    y = y.astype("float32")
    return x, y

# %%
#データセットの作製
k = []
for i in df_list:
    x,y = get_xy(i)
    k.append(y)
# Out:
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data

# %%
#x軸用
x
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999])

# %%
#ディクショナリー型のデータセットを作製　key:value = label:wave
df_dict = dict(zip(data_col,k))

# %%
df_dict
# Out:
# {'table': array([2.74     , 2.7397242, 2.739476 , ..., 2.7407184, 2.740523 ,
#         2.7402754], dtype=float32),
#  'chair': array([2.57     , 2.5694578, 2.5681348, ..., 2.5639122, 2.5674   ,
#         2.569396 ], dtype=float32),
#  'denim': array([2.75     , 2.7526228, 2.7551363, ..., 2.741891 , 2.7445798,
#         2.747303 ], dtype=float32),
#  'cardboard': array([2.73     , 2.7309318, 2.7325096, ..., 2.7320704, 2.7305126,
#         2.7298336], dtype=float32),
#  'pettobottle': array([2.6      , 2.6000354, 2.6002262, ..., 2.601263 , 2.6005878,
#         2.6001723], dtype=float32),
#  'finger': array([2.51     , 2.5046377, 2.5010061, ..., 2.53603  , 2.5258327,
#         2.5170953], dtype=float32),
#  'magic tape': array([2.7      , 2.688871 , 2.6740978, ..., 2.7056985, 2.7086809,
#         2.7067478], dtype=float32),
#  'sponge': array([2.59     , 2.5826423, 2.5749218, ..., 2.6058328, 2.6019464,
#         2.5965645], dtype=float32),
#  'gum tape': array([2.74     , 2.7377923, 2.7361078, ..., 2.74898  , 2.745692 ,
#         2.7426631], dtype=float32),
#  'taoru': array([2.54     , 2.5382605, 2.5356333, ..., 2.537209 , 2.539622 ,
#         2.5405257], dtype=float32)}

# %%
x
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999])

# %%
def show_concat(df_dict):
    plt.figure(figsize=(12,4))
    for i in df_dict:
        plt.plot((x+1)*0.009, df_dict[i],  label=i)
    plt.xlim(81,90)
    plt.ylim(2.4,2.8)
    plt.xlabel("time [s]")
    plt.ylabel("voltage [V]")
    plt.legend(loc='lower left')
    plt.show()

show_concat(df_dict)

# %% [markdown]
# # 標準化

# %%
#データの標準化の一括
share = []
def standard(df_dict,created_list=[]):
    for i in df_dict:
        y = np.array(df_dict[i]).reshape(-1,1)
        y = scale(y)
        a,y= np.array(y)
        y = np.array(y)
        created_list.append(y)
    return created_list

# %%
created_list = standard(df_dict,created_list=[])

# %%
created_list
# Out:
# [array([[0.23061767],
#         [0.21831286],
#         [0.20724173],
#         ...,
#         [0.26266122],
#         [0.25395107],
#         [0.2429012 ]], dtype=float32),
#  array([[ 0.02844481],
#         [ 0.01559269],
#         [-0.01576898],
#         ...,
#         [-0.11586745],
#         [-0.03318773],
#         [ 0.01412888]], dtype=float32),
#  array([[0.50381804],
#         [0.6317402 ],
#         [0.75432503],
#         ...,
#         [0.10831872],
#         [0.2394619 ],
#         [0.37227952]], dtype=float32),
#  array([[0.6463053 ],
#         [0.70781577],
#         [0.8119806 ],
#         ...,
#         [0.78298825],
#         [0.6801455 ],
#         [0.63531905]], dtype=float32),
#  array([[0.55679977],
#         [0.5573554 ],
#         [0.56033856],
#         ...,
#         [0.5765559 ],
#         [0.56599545],
#         [0.5594958 ]], dtype=float32),
#  array([[-0.256236  ],
#         [-0.34580612],
#         [-0.40646738],
#         ...,
#         [ 0.17856422],
#         [ 0.00822918],
#         [-0.1377171 ]], dtype=float32),
#  array([[2.1094017],
#         [1.9331833],
#         [1.6992661],
#         ...,
#         [2.1996307],
#         [2.2468536],
#         [2.216245 ]], dtype=float32),
#  array([[0.45818907],
#         [0.27934635],
#         [0.09168319],
#         ...,
#         [0.8430428 ],
#         [0.7485738 ],
#         [0.61775666]], dtype=float32),
#  array([[-0.8979088 ],
#         [-1.0345294 ],
#         [-1.1387653 ],
#         ...,
#         [-0.34220526],
#         [-0.5456756 ],
#         [-0.7331084 ]], dtype=float32),
#  array([[0.33457378],
#         [0.26836282],
#         [0.1683658 ],
#         ...,
#         [0.22834225],
#         [0.32018995],
#         [0.35458407]], dtype=float32)]

# %%
#ディクショナリー型のデータセットを作製　key:value = label:wave
df_dict_std = dict(zip(data_col, created_list))

# %%
def show_concat_std(df_dict_std):
    plt.figure(figsize=(12,4))
    for i in df_dict:
        plt.plot((x+1)*0.009, df_dict_std[i],  label=i)
    plt.xlim(1,2)
    plt.ylim(-2,2)
    plt.xlabel("time [s]")
    plt.ylabel("voltage_std [V]")
    plt.legend()
    plt.show()

show_concat_std(df_dict_std)

# %% [markdown]
# # DataSetの合成

# %%
#名前をラベルにしたDataSet
def make_dataset_name(time_steps,df_dict):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(len(df_dict[i])-maxlen):
            data.append(df_dict[i][j:j + maxlen])
            target.append(i)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z


#ラベルを数値にしたDataSet
def make_dataset(time_steps,df_dict):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(len(df_dict[i])-maxlen):
            data.append(df_dict[i][j:j + maxlen])
            target.append(h)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z


#ラベルを数値にしたDataSet ストライド付き
def make_dataset_stride(time_steps,df_dict,stride):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(int((len(df_dict[i])-maxlen)/int(stride))):
            data.append(df_dict[i][j*stride:j*stride + maxlen])
            target.append(h)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z

# %%
x,y,z=make_dataset(100,df_dict_std)

# %%
xx,yy,zz=make_dataset_stride(100,df_dict_std,5)

# %%
zz[0].shape
# Out:
# (1980, 101)

# %%
zz[0]
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.230618  0.218313  0.207242  0.198510  0.193001  0.191268  0.193448
# 1     0.191268  0.193448  0.199297  0.208135  0.218983  0.230618  0.241742
# 2     0.230618  0.241742  0.251090  0.257641  0.260694  0.260034  0.255972
# 3     0.260034  0.255972  0.249389  0.241689  0.234712  0.230618  0.231681
# 4     0.230618  0.231681  0.240136  0.257918  0.286494  0.326706  0.378626
# ...        ...       ...       ...       ...       ...       ...       ...
# 1975  0.258790  0.257110  0.252919  0.246666  0.238987  0.230618  0.222375
# 1976  0.230618  0.222375  0.215027  0.209284  0.205657  0.204498  0.205870
# 1977  0.204498  0.205870  0.209635  0.215420  0.222641  0.230618  0.238562
# 1978  0.230618  0.238562  0.245698  0.251356  0.254983  0.256227  0.254972
# 1979  0.256227  0.254972  0.251335  0.245677  0.238541  0.230618  0.222684
#
#              7         8         9  ...        91        92        93  \
# 0     0.199297  0.208135  0.218983  ... -0.254715 -0.284812 -0.305115
# 1     0.251090  0.257641  0.260694  ... -0.308911 -0.293810 -0.272422
# 2     0.249389  0.241689  0.234712  ... -0.181790 -0.145546 -0.107036
# 3     0.240136  0.257918  0.286494  ...  0.022234  0.070421  0.121342
# 4     0.441501  0.513777  0.593136  ...  0.287877  0.345700  0.402864
# ...        ...       ...       ...  ...       ...       ...       ...
# 1975  0.215027  0.209284  0.205657  ...  0.198563  0.203190  0.210571
# 1976  0.209635  0.215420  0.222641  ...  0.241338  0.251133  0.259013
# 1977  0.245698  0.251356  0.254983  ...  0.264597  0.259683  0.251856
# 1978  0.251335  0.245677  0.238541  ...  0.219259  0.208880  0.200531
# 1979  0.215505  0.209784  0.206083  ...  0.194671  0.199872  0.208167
#
#             94        95        96        97        98        99  LABEL
# 0    -0.315537 -0.316526 -0.308911 -0.293810 -0.272422 -0.245941      0
# 1    -0.245941 -0.215450 -0.181790 -0.145546 -0.107036 -0.066314      0
# 2    -0.066314 -0.023285  0.022234  0.070421  0.121342  0.174879      0
# 3     0.174879  0.230618  0.287877  0.345700  0.402864  0.458007      0
# 4     0.458007  0.509704  0.556562  0.597390  0.631295  0.657755      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1975  0.220014  0.230618  0.241338  0.251133  0.259013  0.264203      0
# 1976  0.264203  0.266139  0.264597  0.259683  0.251856  0.241848      0
# 1977  0.241848  0.230618  0.219259  0.208880  0.200531  0.195054      0
# 1978  0.195054  0.193023  0.194671  0.199872  0.208167  0.218749      0
# 1979  0.218749  0.230618  0.242593  0.253494  0.262246  0.267936      0
#
# [1980 rows x 101 columns]

# %%
z[1]
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.028445  0.015593 -0.015769 -0.055026 -0.090638 -0.111284 -0.106955
# 1     0.015593 -0.015769 -0.055026 -0.090638 -0.111284 -0.106955 -0.069930
# 2    -0.015769 -0.055026 -0.090638 -0.111284 -0.106955 -0.069930  0.004425
# 3    -0.055026 -0.090638 -0.111284 -0.106955 -0.069930  0.004425  0.117149
# 4    -0.090638 -0.111284 -0.106955 -0.069930  0.004425  0.117149  0.265497
# ...        ...       ...       ...       ...       ...       ...       ...
# 9895  1.018137  0.840728  0.644171  0.436932  0.228455  0.028445 -0.153887
# 9896  0.840728  0.644171  0.436932  0.228455  0.028445 -0.153887 -0.310577
# 9897  0.644171  0.436932  0.228455  0.028445 -0.153887 -0.310577 -0.435531
# 9898  0.436932  0.228455  0.028445 -0.153887 -0.310577 -0.435531 -0.525061
# 9899  0.228455  0.028445 -0.153887 -0.310577 -0.435531 -0.525061 -0.578182
#
#              7         8         9  ...        91        92        93  \
# 0    -0.069930  0.004425  0.117149  ... -0.204222 -0.170854 -0.111267
# 1     0.004425  0.117149  0.265497  ... -0.170854 -0.111267 -0.030170
# 2     0.117149  0.265497  0.443092  ... -0.111267 -0.030170  0.066103
# 3     0.265497  0.443092  0.640362  ... -0.030170  0.066103  0.170039
# 4     0.443092  0.640362  0.845295  ...  0.066103  0.170039  0.273466
# ...        ...       ...       ...  ...       ...       ...       ...
# 9895 -0.310577 -0.435531 -0.525061  ... -1.103814 -1.208586 -1.250047
# 9896 -0.435531 -0.525061 -0.578182  ... -1.208586 -1.250047 -1.230656
# 9897 -0.525061 -0.578182 -0.596720  ... -1.250047 -1.230656 -1.156816
# 9898 -0.578182 -0.596720 -0.585168  ... -1.230656 -1.156816 -1.038270
# 9899 -0.596720 -0.585168 -0.550302  ... -1.156816 -1.038270 -0.887283
#
#             94        95        96        97        98        99  LABEL
# 0    -0.030170  0.066103  0.170039  0.273466  0.368224  0.446715      1
# 1     0.066103  0.170039  0.273466  0.368224  0.446715  0.502549      1
# 2     0.170039  0.273466  0.368224  0.446715  0.502549  0.530989      1
# 3     0.273466  0.368224  0.446715  0.502549  0.530989  0.529344      1
# 4     0.368224  0.446715  0.502549  0.530989  0.529344  0.497152      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 9895 -1.230656 -1.156816 -1.038270 -0.887283 -0.717623 -0.543390      1
# 9896 -1.156816 -1.038270 -0.887283 -0.717623 -0.543390 -0.377878      1
# 9897 -1.038270 -0.887283 -0.717623 -0.543390 -0.377878 -0.232497      1
# 9898 -0.887283 -0.717623 -0.543390 -0.377878 -0.232497 -0.115867      1
# 9899 -0.717623 -0.543390 -0.377878 -0.232497 -0.115867 -0.033188      1
#
# [9900 rows x 101 columns]

# %% [markdown]
# # 再利用可能なようにcsvファイルとして登録

# %%
con = pd.DataFrame(index=[], columns=[])

# %%
def make_csv(name,dataset,data_col,save_data=False):
    con = pd.DataFrame(index=[], columns=[])
    for i,j in enumerate(dataset):
        #save_dataをTrueにすると作製
        con=pd.concat([con,j])
        if save_data:
            j.to_csv("{}{}.csv".format(data_col[i],name))
    return con

# %%
conm = make_csv("テストだよ",zz,data_col)

# %%
conm
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.230618  0.218313  0.207242  0.198510  0.193001  0.191268  0.193448
# 1     0.191268  0.193448  0.199297  0.208135  0.218983  0.230618  0.241742
# 2     0.230618  0.241742  0.251090  0.257641  0.260694  0.260034  0.255972
# 3     0.260034  0.255972  0.249389  0.241689  0.234712  0.230618  0.231681
# 4     0.230618  0.231681  0.240136  0.257918  0.286494  0.326706  0.378626
# ...        ...       ...       ...       ...       ...       ...       ...
# 1975 -1.370222 -1.384551 -1.378915 -1.347380 -1.284908 -1.187951 -1.055103
# 1976 -1.187951 -1.055103 -0.887561 -0.689354 -0.467435 -0.231395  0.006977
# 1977 -0.231395  0.006977  0.234386  0.436985  0.601269  0.715205  0.769165
# 1978  0.715205  0.769165  0.756759  0.675511  0.527181  0.317840  0.057606
# 1979  0.317840  0.057606 -0.239953 -0.558630 -0.880682 -1.187951 -1.463140
#
#              7         8         9  ...        91        92        93  \
# 0     0.199297  0.208135  0.218983  ... -0.254715 -0.284812 -0.305115
# 1     0.251090  0.257641  0.260694  ... -0.308911 -0.293810 -0.272422
# 2     0.249389  0.241689  0.234712  ... -0.181790 -0.145546 -0.107036
# 3     0.240136  0.257918  0.286494  ...  0.022234  0.070421  0.121342
# 4     0.441501  0.513777  0.593136  ...  0.287877  0.345700  0.402864
# ...        ...       ...       ...  ...       ...       ...       ...
# 1975 -0.887561 -0.689354 -0.467435  ... -1.719109 -1.403490 -1.001197
# 1976  0.234386  0.436985  0.601269  ...  0.444045  0.899726  1.291665
# 1977  0.756759  0.675511  0.527181  ...  1.871982  1.832433  1.679592
# 1978 -0.239953 -0.558630 -0.880682  ...  0.710495  0.299363 -0.108720
# 1979 -1.690931 -1.859008 -1.958869  ... -1.059967 -1.224723 -1.298638
#
#             94        95        96        97        98        99  LABEL
# 0    -0.315537 -0.316526 -0.308911 -0.293810 -0.272422 -0.245941      0
# 1    -0.245941 -0.215450 -0.181790 -0.145546 -0.107036 -0.066314      0
# 2    -0.066314 -0.023285  0.022234  0.070421  0.121342  0.174879      0
# 3     0.174879  0.230618  0.287877  0.345700  0.402864  0.458007      0
# 4     0.458007  0.509704  0.556562  0.597390  0.631295  0.657755      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1975 -0.538583 -0.046057  0.444045  0.899726  1.291665  1.595213      9
# 1976  1.595213  1.792167  1.871982  1.832433  1.679592  1.427281      9
# 1977  1.427281  1.095836  0.710495  0.299363 -0.108720 -0.486384      9
# 1978 -0.486384 -0.809725 -1.059967 -1.224723 -1.298638 -1.283547      9
# 1979 -1.283547 -1.187951 -1.026036 -0.816277 -0.579674 -0.337935      9
#
# [19800 rows x 101 columns]

# %%
def make_data(concat):
    ex = concat.iloc[:,:-1]
    ex = np.array(ex)
    ex=ex.reshape(-1,ex.shape[1],1)
    label = concat.iloc[:,-1]
    label = np.array(label)
    label = label.reshape(-1,1)
    label =one_hot(label)
    
    return ex,label

ex,label = make_data(conm)

# %%
X_train, X_test, Y_train, Y_test = split(ex,label)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
# Out:
# シャッフルする:1 シャッフルしない:21
# testサイズを選んでください0.1

# %%
X_test.shape
# Out:
# (1980, 100, 1)

# %% [markdown]
# # LSTM系列

# %%
from tensorflow.keras.optimizers import RMSprop,Adam
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Bidirectional,LSTM,TimeDistributed
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
class Deep:
    
    def __init__(self,batchsize=32,unit=256,label_num=10,dropout=0.3,epochs=30):
        self.batchsize = batchsize
        self.unit = unit
        self.label_num = label_num
        self.dropout = dropout
        self.es = EarlyStopping(monitor='val_loss', patience=3, verbose=0, mode='auto')
        self.epochs = epochs
    
    def lstm(self,X_train):
        optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
        model = Sequential()
        model.add(LSTM(self.unit, input_shape = (X_train.shape[1], X_train.shape[2]), return_sequences = False))
        model.add(Dropout(self.dropout))
        model.add(Dense(self.label_num))
        model.add(Activation("softmax"))
        model.compile(loss = "categorical_crossentropy", optimizer = optimizer, metrics = ['accuracy'])
        model.summary()
        return model
    
    def learn(self,model,X_train, Y_train,validation_split):
        history = model.fit(X_train, Y_train, batch_size=self.batchsize, epochs=self.epochs,validation_split=validation_split,callbacks=self.es)
        return history
    
    def plot_history(self,history):
    # model loss graph

        def plot_history_loss(fit):
            axL.plot(fit.history['loss'], label="loss for training")
            axL.plot(fit.history['val_loss'],label="loss for validation")
            axL.set_title('model loss')
            axL.set_xlabel('epoch')
            axL.set_ylabel('loss')
            axL.legend(loc='upper right')

        # model accuracy graph

        def plot_history_accuracy(fit):
            axR.plot(fit.history['accuracy'],
                     label="accuracy for training")
            axR.plot(fit.history['val_accuracy'],label="accuracy for validation")
            axR.set_title('model accuracy')
            axR.set_xlabel('epoch')
            axR.set_ylabel('accuracy')
            axR.legend(loc='lower right')

        ig, (axL, axR) = plt.subplots(ncols=2, figsize=(10, 5))
        plt.subplots_adjust(wspace=0.5)
        plot_history_loss(history)
        plot_history_accuracy(history)
        
    def model_save(self,model,model_name):
        model.save("{}.h5".format(model_name))
        model.save_weights("{}_weight.h5".format(model_name))
    
    def test(self,model,X_test,Y_test):
        evaluate_model(model,X_test,Y_test)

# %%
ls = Deep(epochs=30)

# %%
model = load_model("model_100_5_学習2test.h5")
model.load_weights("model_100_5_学習2test_weight.h5")

# %%
history = ls.learn(model,X_train, Y_train,validation_split=0.1)
# Out:
# Epoch 1/30
# 502/502 [==============================] - 21s 42ms/step - loss: 1.4404 - accuracy: 0.5284 - val_loss: 1.0515 - val_accuracy: 0.6364
# Epoch 2/30
# 502/502 [==============================] - 21s 43ms/step - loss: 0.9329 - accuracy: 0.6735 - val_loss: 0.9591 - val_accuracy: 0.6846
# Epoch 3/30
# 502/502 [==============================] - 22s 44ms/step - loss: 0.7652 - accuracy: 0.7340 - val_loss: 0.8601 - val_accuracy: 0.7132
# Epoch 4/30
# 502/502 [==============================] - 22s 44ms/step - loss: 0.6497 - accuracy: 0.7788 - val_loss: 0.6580 - val_accuracy: 0.7767
# Epoch 5/30
# 502/502 [==============================] - 24s 48ms/step - loss: 0.5598 - accuracy: 0.8079 - val_loss: 0.5629 - val_accuracy: 0.8120
# Epoch 6/30
# 502/502 [==============================] - 24s 48ms/step - loss: 0.5024 - accuracy: 0.8315 - val_loss: 0.4669 - val_accuracy: 0.8423
# Epoch 7/30
# 502/502 [==============================] - 24s 47ms/step - loss: 0.4279 - accuracy: 0.8564 - val_loss: 0.4992 - val_accuracy: 0.8423
# Epoch 8/30
# 502/502 [==============================] - 22s 44ms/step - loss: 0.3823 - accuracy: 0.8723 - val_loss: 0.4509 - val_accuracy: 0.8474
# Epoch 9/30
# 502/502 [==============================] - 21s 41ms/step - loss: 0.3373 - accuracy: 0.8903 - val_loss: 0.4131 - val_accuracy: 0.8614
# Epoch 10/30
# 502/502 [==============================] - 21s 42ms/step - loss: 0.3050 - accuracy: 0.9010 - val_loss: 0.3623 - val_accuracy: 0.8900
# Epoch 11/30
# 502/502 [==============================] - 22s 43ms/step - loss: 0.2744 - accuracy: 0.9117 - val_loss: 0.4088 - val_accuracy: 0.8760
# Epoch 12/30
# 502/502 [==============================] - 25s 49ms/step - loss: 0.2552 - accuracy: 0.9202 - val_loss: 0.3280 - val_accuracy: 0.8934
# Epoch 13/30
# 502/502 [==============================] - 23s 46ms/step - loss: 0.2281 - accuracy: 0.9279 - val_loss: 0.3230 - val_accuracy: 0.9068
# Epoch 14/30
# 502/502 [==============================] - 21s 41ms/step - loss: 0.2080 - accuracy: 0.9338 - val_loss: 0.2876 - val_accuracy: 0.9113
# Epoch 15/30
# 502/502 [==============================] - 21s 42ms/step - loss: 0.1951 - accuracy: 0.9400 - val_loss: 0.3289 - val_accuracy: 0.8962
# Epoch 16/30
# 502/502 [==============================] - 24s 48ms/step - loss: 0.1742 - accuracy: 0.9473 - val_loss: 0.2363 - val_accuracy: 0.9214
# Epoch 17/30
# 502/502 [==============================] - 22s 43ms/step - loss: 0.1675 - accuracy: 0.9485 - val_loss: 0.2526 - val_accuracy: 0.9214
# Epoch 18/30
# 502/502 [==============================] - 20s 41ms/step - loss: 0.1494 - accuracy: 0.9559 - val_loss: 0.2423 - val_accuracy: 0.9242
# Epoch 19/30
# 502/502 [==============================] - 21s 41ms/step - loss: 0.1331 - accuracy: 0.9601 - val_loss: 0.2846 - val_accuracy: 0.9181

# %%
ls.test(model,X_test,Y_test)
# Out:
# 62/62 [==============================] - 1s 14ms/step - loss: 0.3148 - accuracy: 0.9076
# loss: 0.31483909487724304 accuracy: 0.907575786113739

# %%
pred = model.predict(X_test)

#予測データ
y_pred = np.argmax(pred,axis=1)

#正解データ
Y_acc = np.argmax(Y_test,axis=1)

class_names = data_col
cf_matrix = confusion_matrix(Y_acc, y_pred)
cd_df = pd.DataFrame(cf_matrix)

cd_df.columns=class_names
cd_df.index=class_names

plt.figure(figsize = (24,14))
sns.heatmap(cd_df.astype('float') / cd_df.sum(axis=1), annot=True, fmt='.2%' ,square = True,cmap='Reds')
plt.show()

# %%
ls.model_save(model,"model_100_5_学習3")

# %%
rr = load_model("model20_3.h5")
rr.load_weights("model_weight20_3.h5")

# %%
ls.test(rr,X_test,Y_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 20, 1) for input Tensor("lstm_3_input:0", shape=(None, 20, 1), dtype=float32), but it was called on an input with incompatible shape (None, 100, 1).
# 62/62 [==============================] - 2s 24ms/step - loss: 9.9442 - accuracy: 0.1101
# loss: 9.944228172302246 accuracy: 0.11010100692510605

# %%
X_test.shape
# Out:
# (652, 19, 1)
