# %%
from modules.load import *
from modules.lstm import *
sns.set()
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.keras.models import load_model

# %%
#標準化前
def plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure(figsize=(12,4))
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(2.4, 2.8)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")

# %%
#標準化後
def standard_plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure()
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(-2.0, 2.0)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")

# %%
ls
# Out:
# 10data_10s.csv
# 10data_2s.csv
# 10data_2s_2.csv
# 2s_time.csv
# 6波形.csv
# 6波形テスト.csv
# 6波形ラベル.csv
# Dockerfile
# S__117538824.jpg
# Untitled1.ipynb
# arduino.ipynb
# arduino.py
# cardboard2.csv
# cardboard3.csv
# cardboard4.csv
# cardboard5.csv
# dan1.csv
# dan2.csv
# dan_std.csv
# denideni2.csv
# denideni3.csv
# denideni4.csv
# denideni5.csv
# denideni6.csv
# denim1.csv
# denim2.csv
# denim_std.csv
# disny_sc.ipynb
# docker-compose.yml
# finger1.csv
# finger2.csv
# finger3.csv
# finger4.csv
# gam_std.csv
# gamgam1.csv
# gamgam2.csv
# gamgam3.csv
# gamgam4.csv
# isu1.csv
# isu2.csv
# isu_std.csv
# isuisu1.csv
# isuisu2.csv
# isuisu3.csv
# isuisu4.csv
# kairo.drawio
# lablab.ipynb
# lstm.ipynb
# lstm_test3&tcn1.ipynb
# lstmモデルの作成.ipynb
# magic1.csv
# magic2.csv
# magic3.csv
# magic4.csv
# magic_std.csv
# mask1.csv
# mask2.csv
# mask3.csv
# model.h5
# model100.h5
# model20.h5
# model20_3.h5
# model20_r.h5
# model_weight.h5
# model_weight100.h5
# model_weight20.h5
# model_weight20_3.h5
# model_weight20_r.h5
# modules/
# note/
# pandas.ipynb
# petto1.csv
# petto2.csv
# petto_std.csv
# pettobb1.csv
# pettobb2.csv
# plan.drawio
# python_vol/
# smonji3.csv
# smonji4.csv
# smonji5.csv
# smonji6.csv
# sponji_std.csv
# tab1.csv
# tab2.csv
# tab3.csv
# table1.csv
# table2.csv
# table_std.csv
# taoru1.csv
# taoru2.csv
# taoru3.csv
# taoru4.csv
# taoru_std.csv
# tcn64.h5
# test.csv
# test10.csv
# test10s.csv
# yubi1.csv
# yubi2.csv
# yubi_std.csv
# yubiyubi1.csv
# yubiyubi10.csv
# yubiyubi11.csv
# yubiyubi12.csv
# yubiyubi13.csv
# yubiyubi14.csv
# yubiyubi2.csv
# yubiyubi3.csv
# yubiyubi4.csv
# yubiyubi5.csv
# yubiyubi6.csv
# yubiyubi7.csv
# yubiyubi8.csv
# yubiyubi9.csv
# 回路.zip
# 章立て.html
# 回路図.png
# モデル0.3.ipynb
# 研究条件めも
# 時系列データ/
# データサイエンス/
# 時系列データ可視化&データの集計.ipynb
# ブレッドボード.png

# %%
data_list = ["tab","isuisu","denideni","cardboard","pettobb","finger","magic","smonji","gamgam",""]

# %%
df = pd.read_csv("10data_2s.csv").iloc[:,1:]

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 1     0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 2     0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 3     0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 4     0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# ...        ...       ...       ...       ...       ...       ...       ...
# 9795 -0.305243 -1.116339 -0.575608  0.505854 -1.116339 -0.305243 -0.845974
# 9796 -1.116339 -0.575608  0.505854 -1.116339 -0.305243 -0.845974 -1.116339
# 9797 -0.575608  0.505854 -1.116339 -0.305243 -0.845974 -1.116339 -1.116339
# 9798  0.505854 -1.116339 -0.305243 -0.845974 -1.116339 -1.116339 -1.116339
# 9799 -1.116339 -0.305243 -0.845974 -1.116339 -1.116339 -1.116339  0.505854
#
#              7         8         9  ...        11        12        13  \
# 0     0.996904  0.996904  0.996904  ... -0.096992  0.267640  0.267640
# 1     0.996904  0.996904  0.996904  ...  0.267640  0.267640  0.267640
# 2     0.996904  0.996904 -0.096992  ...  0.267640  0.267640  0.267640
# 3     0.996904 -0.096992  0.267640  ...  0.267640  0.267640  0.267640
# 4    -0.096992  0.267640  0.267640  ...  0.267640  0.267640  0.267640
# ...        ...       ...       ...  ...       ...       ...       ...
# 9795 -1.116339 -1.116339 -1.116339  ... -1.116339 -0.305243 -0.845974
# 9796 -1.116339 -1.116339  0.505854  ... -0.305243 -0.845974 -1.116339
# 9797 -1.116339  0.505854 -1.116339  ... -0.845974 -1.116339 -0.575608
# 9798  0.505854 -1.116339 -0.305243  ... -1.116339 -0.575608  0.235488
# 9799 -1.116339 -0.305243 -0.845974  ... -0.575608  0.235488 -1.116339
#
#             14        15        16        17        18        19  LABEL
# 0     0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 1     0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 2     0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 3     0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 4     0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 9795 -1.116339 -0.575608  0.235488 -1.116339  0.776219 -1.116339      9
# 9796 -0.575608  0.235488 -1.116339  0.776219 -1.116339 -1.116339      9
# 9797  0.235488 -1.116339  0.776219 -1.116339 -1.116339 -1.116339      9
# 9798 -1.116339  0.776219 -1.116339 -1.116339 -1.116339 -0.034877      9
# 9799  0.776219 -1.116339 -1.116339 -1.116339 -0.034877  0.776219      9
#
# [9800 rows x 21 columns]
