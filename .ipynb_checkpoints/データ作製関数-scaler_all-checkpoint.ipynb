# %%
from modules.load import *
from modules.lstm import *
sns.set()
from tensorflow.keras.models import load_model

# %% [markdown]
# 0:テーブル
# 1:椅子
# 2:デニム
# 3:ダンボール
# 4:ペットボトル
# 5:指
# 6:マジックテープ
# 7:スポンジ
# 8:ガムテープ
# 9:タオル

# %% [markdown]
# # データの集計

# %%
#標準化前
def plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure(figsize=(12,4))
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(2.4, 2.8)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")
        
#標準化後
def standard_plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure()
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(-2.0, 2.0)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")

# %%
def get_xy(data):
    print("data must have only figure data")
    x = data.iloc[:, 0]
    x = signal.resample(x,10000)
    y = data.iloc[:, 1]
    y = signal.resample(y,10000)
    y = y.astype("float32")
    return x, y

# %%
#学習用データ
df_yubi = load("finger1.csv")
df_table = load("tab1.csv")
df_isu = load("isuisu1.csv")
df_petto = load("pettobb1.csv")
df_dan = load("cardboard2.csv")
df_denim = load("denideni2.csv")
df_magic= load("magic1.csv")
df_gam = load("gamgam1.csv")
df_sponji = load("smonji3.csv")
df_taoru = load("taoru1.csv")

# %%
#データを纏める用に作製
df_list = [df_table,df_isu,df_denim,df_dan,df_petto,df_yubi,df_magic,df_sponji,df_gam,df_taoru]
data_col = ["table","chair","denim","cardboard" ,"pettobottle","finger","magic tape" ,"sponge","gum tape","taoru"]

# %%
#データセットの作製
k = []
for i in df_list:
    x,y = get_xy(i)
    k.append(y)
# Out:
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data

# %%
#x軸用
x.shape
# Out:
# (10000,)

# %%
#ディクショナリー型のデータセットを作製　key:value = label:wave
df_dict = dict(zip(data_col,k))

# %%
df_dict
# Out:
# {'table': array([2.73     , 2.7297125, 2.7294466, ..., 2.7307189, 2.7305284,
#         2.730281 ], dtype=float32),
#  'chair': array([2.61     , 2.6142638, 2.6186213, ..., 2.6016245, 2.603395 ,
#         2.606262 ], dtype=float32),
#  'denim': array([2.62     , 2.6097255, 2.6011806, ..., 2.6535447, 2.6427493,
#         2.6312819], dtype=float32),
#  'cardboard': array([2.6      , 2.592213 , 2.5862105, ..., 2.6320717, 2.6202185,
#         2.609418 ], dtype=float32),
#  'pettobottle': array([2.7      , 2.697406 , 2.6933627, ..., 2.6964836, 2.6996963,
#         2.7008343], dtype=float32),
#  'finger': array([2.61     , 2.6093898, 2.6091456, ..., 2.6141295, 2.6123497,
#         2.6109815], dtype=float32),
#  'magic tape': array([2.55     , 2.5446866, 2.5401533, ..., 2.5675154, 2.5617216,
#         2.5557837], dtype=float32),
#  'sponge': array([2.54     , 2.5433295, 2.5463257, ..., 2.531208 , 2.5336294,
#         2.5366588], dtype=float32),
#  'gum tape': array([2.76     , 2.7615473, 2.7624009, ..., 2.751932 , 2.755086 ,
#         2.7578156], dtype=float32),
#  'taoru': array([2.52     , 2.5302086, 2.5392854, ..., 2.4871747, 2.4980102,
#         2.5091097], dtype=float32)}

# %%
df_dict["table"]
# Out:
# array([2.73     , 2.7297125, 2.7294466, ..., 2.7307189, 2.7305284,
#        2.730281 ], dtype=float32)

# %%
u = signal.resample(df_dict["table"],10000)

# %%
x.shape
# Out:
# (10000,)

# %%
u
# Out:
# array([2.7299998, 2.7297127, 2.729447 , ..., 2.7307189, 2.7305284,
#        2.730281 ], dtype=float32)

# %%
u.shape
# Out:
# (10000,)

# %%
x = np.arange(0,10000,1)

# %%
x
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999])

# %%
def show_concat(df_dict):
    plt.figure(figsize=(12,4))
    for i in df_dict:
        plt.plot((x+1)*0.009, df_dict[i],  label=i)
    plt.xlim(0,10)
    plt.ylim(2.4,2.8)
    plt.xlabel("time [s]")
    plt.ylabel("voltage [V]")
    plt.legend()
    plt.show()

show_concat(df_dict)

# %% [markdown]
# # 標準化

# %%
#データの標準化の一括
share = []
def standard(df_dict,created_list=[]):
    for i in df_dict:
        y = np.array(df_dict[i]).reshape(-1,1)
        y = scale(y)
        a,y= np.array(y)
        y = np.array(y)
        created_list.append(y)
    return created_list

# %%
created_list = standard(df_dict,created_list=[])

# %%
created_list
# Out:
# [array([[0.99693125],
#         [0.9864466 ],
#         [0.9767531 ],
#         ...,
#         [1.0231429 ],
#         [1.0161966 ],
#         [1.0071812 ]], dtype=float32),
#  array([[0.7886482 ],
#         [0.8732446 ],
#         [0.95970005],
#         ...,
#         [0.62247795],
#         [0.65760505],
#         [0.7144867 ]], dtype=float32),
#  array([[-1.1977799 ],
#         [-1.3992609 ],
#         [-1.5668266 ],
#         ...,
#         [-0.5399674 ],
#         [-0.75166416],
#         [-0.97654074]], dtype=float32),
#  array([[-1.2520432 ],
#         [-1.433398  ],
#         [-1.5731913 ],
#         ...,
#         [-0.50510794],
#         [-0.7811629 ],
#         [-1.0327029 ]], dtype=float32),
#  array([[0.7649512 ],
#         [0.71689415],
#         [0.641986  ],
#         ...,
#         [0.6998047 ],
#         [0.75932395],
#         [0.78040636]], dtype=float32),
#  array([[0.84771675],
#         [0.8347542 ],
#         [0.8295672 ],
#         ...,
#         [0.9354556 ],
#         [0.89764196],
#         [0.8685713 ]], dtype=float32),
#  array([[ 0.14035499],
#         [ 0.05599238],
#         [-0.01598423],
#         ...,
#         [ 0.4184533 ],
#         [ 0.326463  ],
#         [ 0.23218629]], dtype=float32),
#  array([[-0.7236335 ],
#         [-0.60835385],
#         [-0.50461453],
#         ...,
#         [-1.0280412 ],
#         [-0.94420445],
#         [-0.83931774]], dtype=float32),
#  array([[-0.09365657],
#         [ 0.03689948],
#         [ 0.10891652],
#         ...,
#         [-0.77439874],
#         [-0.50827765],
#         [-0.27796388]], dtype=float32),
#  array([[ 0.77639365],
#         [ 1.0524613 ],
#         [ 1.2979228 ],
#         ...,
#         [-0.11128729],
#         [ 0.18173079],
#         [ 0.48189268]], dtype=float32)]

# %%
#ディクショナリー型のデータセットを作製　key:value = label:wave
df_dict_std = dict(zip(data_col, created_list))

# %%
def show_concat_std(df_dict_std):
    plt.figure(figsize=(12,4))
    for i in df_dict:
        plt.plot((x+1)*0.009, df_dict_std[i],  label=i)
    plt.xlim(0,8)
    plt.ylim(-2,2)
    plt.xlabel("time [s]")
    plt.ylabel("voltage_std [V]")
    plt.legend()
    plt.show()

show_concat_std(df_dict_std)

# %%
x.shape
# Out:
# (10000,)

# %% [markdown]
# # DataSetの合成

# %%
#名前をラベルにしたDataSet
def make_dataset_name(time_steps,df_dict):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(len(df_dict[i])-maxlen):
            data.append(df_dict[i][j:j + maxlen])
            target.append(i)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z


#ラベルを数値にしたDataSet
def make_dataset(time_steps,df_dict):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(len(df_dict[i])-maxlen):
            data.append(df_dict[i][j:j + maxlen])
            target.append(h)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z


#ラベルを数値にしたDataSet ストライド付き
def make_dataset_stride(time_steps,df_dict,stride):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(int((len(df_dict[i])-maxlen)/int(stride))):
            data.append(df_dict[i][j*stride:j*stride + maxlen])
            target.append(h)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z

# %%
x,y,z=make_dataset(20,df_dict_std)

# %%
xx,yy,zz=make_dataset_stride(100,df_dict_std,5)

# %%
zz[0].shape
# Out:
# (1980, 101)

# %%
zz[0]
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.996931  0.986447  0.976753  0.968842  0.963539  0.961426  0.962782
# 1     0.961426  0.962782  0.967564  0.975353  0.985464  0.996931  1.008650
# 2     0.996931  1.008650  1.019465  1.028281  1.034193  1.036531  1.035001
# 3     1.036531  1.035001  1.029672  1.020978  1.009711  0.996931  0.983873
# 4     0.996931  0.983873  0.971824  0.961991  0.955410  0.952793  0.954488
# ...        ...       ...       ...       ...       ...       ...       ...
# 1975  0.342067  0.339919  0.330521  0.314447  0.292904  0.267648  0.240872
# 1976  0.267648  0.240872  0.215008  0.192569  0.175886  0.166966  0.167314
# 1977  0.166966  0.167314  0.177781  0.198507  0.228892  0.267648  0.312899
# 1978  0.267648  0.312899  0.362314  0.413312  0.463231  0.509586  0.550212
# 1979  0.509586  0.550212  0.583457  0.608321  0.624465  0.632290  0.632838
#
#              7         8         9  ...        91        92        93  \
# 0     0.967564  0.975353  0.985464  ...  1.046746  1.096631  1.141821
# 1     1.019465  1.028281  1.034193  ...  1.202460  1.185012  1.144907
# 2     1.029672  1.020978  1.009711  ...  0.892763  0.773181  0.643044
# 3     0.971824  0.961991  0.955410  ...  0.246662  0.131843  0.034091
# 4     0.960426  0.970111  0.982674  ... -0.127073 -0.133681 -0.118658
# ...        ...       ...       ...  ...       ...       ...       ...
# 1975  0.215008  0.192569  0.175886  ...  0.978266  0.980665  0.984830
# 1976  0.177781  0.198507  0.228892  ...  1.003721  1.010102  1.015414
# 1977  0.362314  0.413312  0.463231  ...  1.019883  1.016796  1.011606
# 1978  0.583457  0.608321  0.624465  ...  0.988837  0.981300  0.975101
# 1979  0.627734  0.619006  0.608921  ...  0.970146  0.973832  0.979918
#
#             94        95        96        97        98        99  LABEL
# 0     1.177448  1.198965  1.202460  1.185012  1.144907  1.081834      0
# 1     1.081834  0.996931  0.892763  0.773181  0.643044  0.507961      0
# 2     0.507961  0.373860  0.246662  0.131843  0.034091 -0.042962      0
# 3    -0.042962 -0.096993 -0.127073 -0.133681 -0.118658 -0.084978      0
# 4    -0.084978 -0.036537  0.022181  0.086427  0.151500  0.213121      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1975  0.990428  0.996931  1.003721  1.010102  1.015414  1.019074      0
# 1976  1.019074  1.020639  1.019883  1.016796  1.011606  1.004773      0
# 1977  1.004773  0.996931  0.988837  0.981300  0.975101  0.970885      0
# 1978  0.970885  0.969155  0.970146  0.973832  0.979918  0.987864      0
# 1979  0.987864  0.996931  1.006234  1.014849  1.021900  1.026646      0
#
# [1980 rows x 101 columns]

# %%
z[1]
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.788648  0.873245  0.959700  1.038544  1.100336  1.136551  1.140430
# 1     0.873245  0.959700  1.038544  1.100336  1.136551  1.140430  1.107611
# 2     0.959700  1.038544  1.100336  1.136551  1.140430  1.107611  1.036577
# 3     1.038544  1.100336  1.136551  1.140430  1.107611  1.036577  0.928807
# 4     1.100336  1.136551  1.140430  1.107611  1.036577  0.928807  0.788648
# ...        ...       ...       ...       ...       ...       ...       ...
# 9975 -0.595012 -0.652684 -0.660584 -0.618489 -0.529909 -0.401766 -0.243713
# 9976 -0.652684 -0.660584 -0.618489 -0.529909 -0.401766 -0.243713 -0.067283
# 9977 -0.660584 -0.618489 -0.529909 -0.401766 -0.243713 -0.067283  0.115136
# 9978 -0.618489 -0.529909 -0.401766 -0.243713 -0.067283  0.115136  0.291386
# 9979 -0.529909 -0.401766 -0.243713 -0.067283  0.115136  0.291386  0.450551
#
#              7         8         9  ...        11        12        13  \
# 0     1.107611  1.036577  0.928807  ...  0.622960  0.440466  0.250976
# 1     1.036577  0.928807  0.788648  ...  0.440466  0.250976  0.064531
# 2     0.928807  0.788648  0.622960  ...  0.250976  0.064531 -0.109510
# 3     0.788648  0.622960  0.440466  ...  0.064531 -0.109510 -0.263263
# 4     0.622960  0.440466  0.250976  ... -0.109510 -0.263263 -0.390990
# ...        ...       ...       ...  ...       ...       ...       ...
# 9975 -0.067283  0.115136  0.291386  ...  0.583874  0.685410  0.752452
# 9976  0.115136  0.291386  0.450551  ...  0.685410  0.752452  0.785621
# 9977  0.291386  0.450551  0.583874  ...  0.752452  0.785621  0.788648
# 9978  0.450551  0.583874  0.685410  ...  0.785621  0.788648  0.767896
# 9979  0.583874  0.685410  0.752452  ...  0.788648  0.767896  0.731601
#
#             14        15        16        17        18        19  LABEL
# 0     0.064531 -0.109510 -0.263263 -0.390990 -0.489532 -0.558490      1
# 1    -0.109510 -0.263263 -0.390990 -0.489532 -0.558490 -0.600168      1
# 2    -0.263263 -0.390990 -0.489532 -0.558490 -0.600168 -0.619198      1
# 3    -0.390990 -0.489532 -0.558490 -0.600168 -0.619198 -0.621980      1
# 4    -0.489532 -0.558490 -0.600168 -0.619198 -0.621980 -0.615944      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 9975  0.785621  0.788648  0.767896  0.731601  0.689009  0.649393      1
# 9976  0.788648  0.767896  0.731601  0.689009  0.649393  0.621116      1
# 9977  0.767896  0.731601  0.689009  0.649393  0.621116  0.610756      1
# 9978  0.731601  0.689009  0.649393  0.621116  0.610756  0.622478      1
# 9979  0.689009  0.649393  0.621116  0.610756  0.622478  0.657605      1
#
# [9980 rows x 21 columns]

# %% [markdown]
# # 再利用可能なようにcsvファイルとして登録

# %%
con = pd.DataFrame(index=[], columns=[])

# %%
def make_csv(name,dataset,data_col,save_data=False):
    con = pd.DataFrame(index=[], columns=[])
    for i,j in enumerate(dataset):
        #save_dataをTrueにすると作製
        con=pd.concat([con,j])
        if save_data:
            j.to_csv("{}{}.csv".format(data_col[i],name))
    return con

# %%
conm = make_csv("テストだよ",zz,data_col)

# %%
conm
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.996931  0.986447  0.976753  0.968842  0.963539  0.961426  0.962782
# 1     0.961426  0.962782  0.967564  0.975353  0.985464  0.996931  1.008650
# 2     0.996931  1.008650  1.019465  1.028281  1.034193  1.036531  1.035001
# 3     1.036531  1.035001  1.029672  1.020978  1.009711  0.996931  0.983873
# 4     0.996931  0.983873  0.971824  0.961991  0.955410  0.952793  0.954488
# ...        ...       ...       ...       ...       ...       ...       ...
# 1975 -0.477123 -0.558864 -0.641527 -0.719503 -0.788555 -0.846163 -0.891586
# 1976 -0.846163 -0.891586 -0.925757 -0.950954 -0.970367 -0.987518 -1.005667
# 1977 -0.987518 -1.005667 -1.027266 -1.053488 -1.083959 -1.116589 -1.147731
# 1978 -1.116589 -1.147731 -1.172425 -1.184933 -1.179304 -1.150110 -1.093121
# 1979 -1.150110 -1.093121 -1.005938 -0.888491 -0.743339 -0.575737 -0.393441
#
#              7         8         9  ...        91        92        93  \
# 0     0.967564  0.975353  0.985464  ...  1.046746  1.096631  1.141821
# 1     1.019465  1.028281  1.034193  ...  1.202460  1.185012  1.144907
# 2     1.029672  1.020978  1.009711  ...  0.892763  0.773181  0.643044
# 3     0.971824  0.961991  0.955410  ...  0.246662  0.131843  0.034091
# 4     0.960426  0.970111  0.982674  ... -0.127073 -0.133681 -0.118658
# ...        ...       ...       ...  ...       ...       ...       ...
# 1975 -0.925757 -0.950954 -0.970367  ... -0.890316 -0.714661 -0.507226
# 1976 -1.027266 -1.053488 -1.083959  ...  0.207192  0.436876  0.642261
# 1977 -1.172425 -1.184933 -1.179304  ...  1.014686  1.035904  1.001552
# 1978 -1.005938 -0.888491 -0.743339  ...  0.597360  0.385613  0.151956
# 1979 -0.206278 -0.025465  0.137211  ... -0.560418 -0.761721 -0.926924
#
#             94        95        96        97        98        99  LABEL
# 0     1.177448  1.198965  1.202460  1.185012  1.144907  1.081834      0
# 1     1.081834  0.996931  0.892763  0.773181  0.643044  0.507961      0
# 2     0.507961  0.373860  0.246662  0.131843  0.034091 -0.042962      0
# 3    -0.042962 -0.096993 -0.127073 -0.133681 -0.118658 -0.084978      0
# 4    -0.084978 -0.036537  0.022181  0.086427  0.151500  0.213121      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1975 -0.277019 -0.034885  0.207192  0.436876  0.642261  0.812596      9
# 1976  0.812596  0.938941  1.014686  1.035904  1.001552  0.913499      9
# 1977  0.913499  0.776394  0.597360  0.385613  0.151956 -0.091771      9
# 1978 -0.091771 -0.333280 -0.560418 -0.761721 -0.926924 -1.047421      9
# 1979 -1.047421 -1.116589 -1.130097 -1.086074 -0.985171 -0.830573      9
#
# [19800 rows x 101 columns]

# %%
def make_data(concat):
    ex = concat.iloc[:,:-1]
    ex = np.array(ex)
    ex=ex.reshape(-1,ex.shape[1],1)
    label = concat.iloc[:,-1]
    label = np.array(label)
    label = label.reshape(-1,1)
    label =one_hot(label)
    
    return ex,label

ex,label = make_data(conm)

# %%
X_train, X_test, Y_train, Y_test = split(ex,label)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
# Out:
# シャッフルする:1 シャッフルしない:21
# testサイズを選んでください0.2

# %%
X_train.shape
# Out:
# (15840, 100, 1)

# %% [markdown]
# # LSTM系列

# %%
from tensorflow.keras.optimizers import RMSprop,Adam
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Bidirectional,LSTM,TimeDistributed
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# バッチサイズについて
# https://qiita.com/kenta1984/items/bad75a37d552510e4682
#
# バッチサイズは機械学習の分野の慣習1として2のn乗の値が使われることが多く、32, 64, 128, 256, 512, 1024, 2048辺りがよく使われる数値だと思います。

# %%
class Deep:
    
    def __init__(self,batchsize=64,unit=128,label_num=10,dropout=0.2,epochs=30):
        self.batchsize = batchsize
        self.unit = unit
        self.label_num = label_num
        self.dropout = dropout
        self.es = EarlyStopping(monitor='val_loss', patience=3, verbose=0, mode='auto')
        self.epochs = epochs
    
    def lstm(self,X_train):
#         optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
        optimizer = RMSprop(learning_rate=0.001)
        model = Sequential()
        model.add(LSTM(self.unit, input_shape = (X_train.shape[1], X_train.shape[2]), return_sequences = False))
        model.add(Dropout(self.dropout))
        model.add(Dense(self.label_num))
        model.add(Activation("softmax"))
        model.compile(loss = "categorical_crossentropy", optimizer = optimizer, metrics = ['accuracy'])
        model.summary()
        return model
    
    def learn(self,model,X_train, Y_train,validation_split):
        history = model.fit(X_train, Y_train, batch_size=self.batchsize, epochs=self.epochs,validation_split=validation_split,callbacks=self.es)
        return history
    
    def plot_history(self,history):
    # model loss graph

        def plot_history_loss(fit):
            axL.plot(fit.history['loss'], label="loss for training")
            axL.plot(fit.history['val_loss'],label="loss for validation")
            axL.set_title('model loss')
            axL.set_xlabel('epoch')
            axL.set_ylabel('loss')
            axL.legend(loc='upper right')

        # model accuracy graph

        def plot_history_accuracy(fit):
            axR.plot(fit.history['accuracy'],
                     label="accuracy for training")
            axR.plot(fit.history['val_accuracy'],label="accuracy for validation")
            axR.set_title('model accuracy')
            axR.set_xlabel('epoch')
            axR.set_ylabel('accuracy')
            axR.legend(loc='lower right')

        ig, (axL, axR) = plt.subplots(ncols=2, figsize=(10, 5))
        plt.subplots_adjust(wspace=0.5)
        plot_history_loss(history)
        plot_history_accuracy(history)
        
    def model_save(self,model,model_name):
        model.save("{}.h5".format(model_name))
        model.save_weights("{}_weight.h5".format(model_name))
    
    def test(self,model,X_test,Y_test):
        evaluate_model(model,X_test,Y_test)

# %%
ls = Deep(epochs=100)

# %%
model = ls.lstm(X_train)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_11 (LSTM)               (None, 128)               66560
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_11 (Activation)   (None, 10)                0
# =================================================================
# Total params: 67,850
# Trainable params: 67,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = ls.learn(model,X_train, Y_train,validation_split=0.1)
# Out:
# Epoch 1/100
# 223/223 [==============================] - 14s 61ms/step - loss: 2.0456 - accuracy: 0.2200 - val_loss: 1.8547 - val_accuracy: 0.2778
# Epoch 2/100
# 223/223 [==============================] - 14s 65ms/step - loss: 1.7865 - accuracy: 0.3089 - val_loss: 1.7251 - val_accuracy: 0.3396
# Epoch 3/100
# 223/223 [==============================] - 17s 77ms/step - loss: 1.6540 - accuracy: 0.3721 - val_loss: 1.5686 - val_accuracy: 0.4034
# Epoch 4/100
# 223/223 [==============================] - 22s 97ms/step - loss: 1.5377 - accuracy: 0.4200 - val_loss: 1.5729 - val_accuracy: 0.4148
# Epoch 5/100
# 223/223 [==============================] - 22s 98ms/step - loss: 1.4660 - accuracy: 0.4547 - val_loss: 1.4339 - val_accuracy: 0.4457
# Epoch 6/100
# 223/223 [==============================] - 16s 70ms/step - loss: 1.3816 - accuracy: 0.4766 - val_loss: 1.3919 - val_accuracy: 0.4609
# Epoch 7/100
# 223/223 [==============================] - 16s 73ms/step - loss: 1.3109 - accuracy: 0.5101 - val_loss: 1.2782 - val_accuracy: 0.5057
# Epoch 8/100
# 223/223 [==============================] - 16s 73ms/step - loss: 1.2529 - accuracy: 0.5309 - val_loss: 1.2852 - val_accuracy: 0.5152
# Epoch 9/100
# 223/223 [==============================] - 16s 71ms/step - loss: 1.1934 - accuracy: 0.5532 - val_loss: 1.2115 - val_accuracy: 0.5461
# Epoch 10/100
# 223/223 [==============================] - 15s 67ms/step - loss: 1.1413 - accuracy: 0.5717 - val_loss: 1.1574 - val_accuracy: 0.5764
# Epoch 11/100
# 223/223 [==============================] - 15s 66ms/step - loss: 1.0817 - accuracy: 0.5957 - val_loss: 1.0479 - val_accuracy: 0.6105
# Epoch 12/100
# 223/223 [==============================] - 16s 71ms/step - loss: 1.0475 - accuracy: 0.6129 - val_loss: 1.1236 - val_accuracy: 0.5928
# Epoch 13/100
# 223/223 [==============================] - 15s 69ms/step - loss: 1.0005 - accuracy: 0.6303 - val_loss: 1.0530 - val_accuracy: 0.6174
# Epoch 14/100
# 223/223 [==============================] - 14s 64ms/step - loss: 0.9662 - accuracy: 0.6443 - val_loss: 1.0057 - val_accuracy: 0.6193
# Epoch 15/100
# 223/223 [==============================] - 14s 62ms/step - loss: 0.9131 - accuracy: 0.6635 - val_loss: 0.9443 - val_accuracy: 0.6402
# Epoch 16/100
# 223/223 [==============================] - 14s 65ms/step - loss: 0.8742 - accuracy: 0.6778 - val_loss: 1.0408 - val_accuracy: 0.6357
# Epoch 17/100
# 223/223 [==============================] - 14s 64ms/step - loss: 0.8348 - accuracy: 0.6963 - val_loss: 0.9047 - val_accuracy: 0.6711
# Epoch 18/100
# 223/223 [==============================] - 14s 62ms/step - loss: 0.7960 - accuracy: 0.7127 - val_loss: 0.8267 - val_accuracy: 0.6963
# Epoch 19/100
# 223/223 [==============================] - 16s 73ms/step - loss: 0.7669 - accuracy: 0.7190 - val_loss: 0.8110 - val_accuracy: 0.7096
# Epoch 20/100
# 223/223 [==============================] - 16s 73ms/step - loss: 0.7485 - accuracy: 0.7269 - val_loss: 0.8135 - val_accuracy: 0.7083
# Epoch 21/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.7112 - accuracy: 0.7447 - val_loss: 0.8628 - val_accuracy: 0.6970
# Epoch 22/100
# 223/223 [==============================] - 15s 69ms/step - loss: 0.6748 - accuracy: 0.7604 - val_loss: 0.7022 - val_accuracy: 0.7557
# Epoch 23/100
# 223/223 [==============================] - 16s 70ms/step - loss: 0.6389 - accuracy: 0.7698 - val_loss: 0.8283 - val_accuracy: 0.6982
# Epoch 24/100
# 223/223 [==============================] - 17s 76ms/step - loss: 0.6051 - accuracy: 0.7887 - val_loss: 0.7635 - val_accuracy: 0.7140
# Epoch 25/100
# 223/223 [==============================] - 15s 66ms/step - loss: 0.5928 - accuracy: 0.7918 - val_loss: 0.6635 - val_accuracy: 0.7569
# Epoch 26/100
# 223/223 [==============================] - 14s 63ms/step - loss: 0.5611 - accuracy: 0.8029 - val_loss: 0.6788 - val_accuracy: 0.7551
# Epoch 27/100
# 223/223 [==============================] - 15s 66ms/step - loss: 0.5443 - accuracy: 0.8111 - val_loss: 0.7332 - val_accuracy: 0.7361
# Epoch 28/100
# 223/223 [==============================] - 15s 66ms/step - loss: 0.5204 - accuracy: 0.8197 - val_loss: 0.6694 - val_accuracy: 0.7626

# %%
ls.plot_history(history)

# %%
ls.test(model,X_test,Y_test)
# Out:
# 124/124 [==============================] - 2s 13ms/step - loss: 0.6329 - accuracy: 0.7841
# loss: 0.6328669786453247 accuracy: 0.7840909361839294

# %%
pred = model.predict(X_test)

#予測データ
y_pred = np.argmax(pred,axis=1)

#正解データ
Y_acc = np.argmax(Y_test,axis=1)

class_names = data_col
cf_matrix = confusion_matrix(Y_acc, y_pred)
cd_df = pd.DataFrame(cf_matrix)

cd_df.columns=class_names
cd_df.index=class_names

plt.figure(figsize = (24,14))
sns.heatmap(cd_df.astype('float') / cd_df.sum(axis=1), annot=True, fmt='.2%' ,square = True,cmap='Reds')
plt.show()

# %%
ls.model_save(model,"model_100_5学習1")

# %%
rr = load_model("model_300_30学習1.h5")
rr.load_weights("model_300_30学習1_weight.h5")

# %%
ls.test(rr,X_test,Y_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 300, 1) for input Tensor("lstm_14_input:0", shape=(None, 300, 1), dtype=float32), but it was called on an input with incompatible shape (None, 100, 1).
# 21/21 [==============================] - 0s 15ms/step - loss: 1.7148 - accuracy: 0.5045
# loss: 1.7147619724273682 accuracy: 0.5045454502105713

# %%
X_test.shape
# Out:
# (660, 100, 1)
