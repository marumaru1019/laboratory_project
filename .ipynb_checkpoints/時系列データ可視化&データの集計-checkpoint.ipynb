# %%
from modules.load import *
from modules.lstm import *
sns.set()

# %%
from tensorflow.keras.models import load_model

# %% [markdown]
# # データの可視化

# %%
#標準化前
def plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure(figsize=(12,4))
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(2.0, 2.7)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")

# %%
#標準化後
def standard_plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure()
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(-2.0, 2.0)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")

# %% [markdown]
# # データの前処理

# %%
#学習用データ
df_yubi = load("yubi1.csv")
df_table = load("table1.csv")
df_isu = load("isu1.csv")
df_petto = load("petto1.csv")
df_dan = load("dan1.csv")
df_denim = load("denim1.csv")

# %%
df_denim
# Out:
#      Unnamed: 0     0
# 0             0  2.29
# 1             1  2.23
# 2             2  2.25
# 3             3  2.11
# 4             4  2.11
# ..          ...   ...
# 995         995  2.17
# 996         996  2.17
# 997         997  2.17
# 998         998  2.17
# 999         999  2.17
#
# [1000 rows x 2 columns]

# %%
#学習用データ
x_yubi , y_yubi = get_xy(df_yubi)
x_table , y_table = get_xy(df_table)
x_denim , y_denim = get_xy(df_denim)
x_isu , y_isu = get_xy(df_isu)
x_dan , y_dan = get_xy(df_dan)
x_petto , y_petto = get_xy(df_petto)
# Out:
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data

# %%
y_isu.shape
# Out:
# (1000,)

# %%
plot_g("chair graph",x_yubi,y_yubi,0,15,save=False)

# %%
plot_g("chair graph",x_isu ,y_isu,0,15,save=False)

# %%
plot_g("chair graph",x_table ,y_table,0,15,save=False)

# %%
plot_g("chair graph",x_dan,y_dan,0,15,save=False)

# %%
plot_g("chair graph",x_dan,y_dan,0,15,save=False)

# %%
plot_g("chair graph",x_denim,y_denim,0,15,save=False)

# %%
plot_g("chair graph",x_petto,y_petto,0,15,save=False)

# %%
x=x_yubi

# %%
print(5/1023)
# Out:
# 0.004887585532746823

# %%
plt.figure(figsize=(12,4))
plt.plot((x+1)*0.09, y_yubi, color="b", label="finger")
plt.plot((x+1)*0.09, y_petto, label="pettobottle")
plt.plot((x+1)*0.09, y_dan, label="cardboard")
plt.plot((x+1)*0.09, y_denim, label="denim")
plt.plot((x+1)*0.09, y_isu, label="chair")
plt.plot((x+1)*0.09, y_table, label="table")
plt.xlim(0,8)
plt.ylim(2.0,2.7)
plt.xlabel("time [s]")
plt.ylabel("voltage [V]")
plt.legend()
plt.show()

# %% [markdown]
# # データの標準化

# %%
#学習データに関して
#numpyに変換
y_yubi = np.array(y_yubi).reshape(-1,1)
y_table = np.array(y_table).reshape(-1,1)
y_denim = np.array(y_denim).reshape(-1,1)
y_isu = np.array(y_isu).reshape(-1,1)
y_dan = np.array(y_dan).reshape(-1,1)
y_petto = np.array(y_petto).reshape(-1,1)

# %%
#標準化
y_yubi = scale(y_yubi)
y_table = scale(y_table)
y_denim = scale(y_denim)
y_isu = scale(y_isu)
y_dan= scale(y_dan)
y_petto = scale(y_petto)

# %%
y_isu
# Out:
# (StandardScaler(),
#              0
#  0    0.475945
#  1    1.175658
#  2    0.056118
#  3    0.336003
#  4    0.755830
#  ..        ...
#  995  1.315601
#  996  1.035715
#  997 -1.903082
#  998 -0.783538
#  999 -2.043024
#
#  [1000 rows x 1 columns])

# %%
a
# Out:
# StandardScaler()

# %%
a,y_yubi = np.array(y_yubi)
b,y_table = np.array(y_table)
c,y_denim = np.array(y_denim)
d,y_isu = np.array(y_isu)
e,y_dan = np.array(y_dan)
f,y_petto = np.array(y_petto)
# Out:
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
standard_plot_g("chair graph",x_isu,y_isu,0,15,save=False)

# %%
plt.figure(figsize=(12,4))
plt.plot((x+1)*0.09, y_yubi, color="b", label="finger")
plt.plot((x+1)*0.09, y_petto, label="pettobottle")
plt.plot((x+1)*0.09, y_dan, label="cardboard")
plt.plot((x+1)*0.09, y_denim, label="denim")
plt.plot((x+1)*0.09, y_isu, label="chair")
plt.plot((x+1)*0.09, y_table, label="table")
plt.xlim(0,10)
plt.ylim(-2.0,2.0)
plt.xlabel("time [ms]")
plt.ylabel("voltage [mV]")
plt.legend()
plt.show()

# %%
import statsmodels.api as sm

# %%
y_table.iloc[100:,0]
# Out:
# 100   -0.706319
# 101   -1.182600
# 102   -1.023837
# 103   -1.341359
# 104   -1.341359
#          ...
# 995    0.404995
# 996    0.881273
# 997    0.722514
# 998    0.881273
# 999    0.881273
# Name: 0, Length: 900, dtype: float32

# %% [markdown]
# # 自己相関

# %% [markdown]
# 図の上が自己相関、下が偏自己相関です。色が塗られている部分は95%信頼区間で、この範囲内だと「相関はない」という帰無仮説が棄却されない事を意味します。
#
# つまりその範囲を超えていれば、帰無仮説が棄却されて、相関があると言えます。
#
# 以下の記事参考
# https://dodotechno.com/python-statsmodels/

# %%
#  自己相関のグラフ
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(y_table.iloc[400:,0], lags=100, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(y_table, lags=100, ax=ax2)

# %%
lvalue, pvalue = sm.stats.diagnostic.acorr_ljungbox(y_table)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/stats/diagnostic.py:533: FutureWarning: The default value of lags is changing.  After 0.12, this value will become min(10, nobs//5). Directly setlags to silence this warning.
#   "lags to silence this warning.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/stats/diagnostic.py:559: FutureWarning: The value returned will change to a single DataFrame after 0.12 is released.  Set return_df to True to use to return a DataFrame now.  Set return_df to False to silence this warning.
#   warnings.warn(msg, FutureWarning)

# %%
#  自己相関のグラフ
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(y_isu, lags=100, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(y_isu, lags=100, ax=ax2)

# %%
#  自己相関のグラフ
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(y_dan, lags=100, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(y_dan, lags=100, ax=ax2)

# %%
#  自己相関のグラフ
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(y_denim, lags=100, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(y_denim, lags=100, ax=ax2)

# %%
#  自己相関のグラフ
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(y_yubi, lags=100, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(y_yubi, lags=100, ax=ax2)

# %% [markdown]
# # LSTMにかけれるようにデータの加工

# %% [markdown]
# 0:テーブル
# 1:椅子
# 2:デニム
# 3:ダンボール
# 4:ペットボトル
# 5:指

# %%
def make_dataset_kai(low_data):
    time_steps = int(input("timesteps:"))
    label_num = int(input("label_num:"))
    data, target = [], []
    maxlen = time_steps

    for i in range(len(low_data)-maxlen):
        data.append(low_data[i:i + maxlen])
        target.append(label_num)

    re_data = np.array(data).reshape(len(data), maxlen, 1)
    re_target = np.array(target).reshape(len(data), )
    csv_data = np.array(data).reshape(len(data), maxlen)
    csv_data=pd.DataFrame(csv_data)
    csv_data["LABEL"] =re_target
    

    return re_data, re_target,csv_data

# %%
#テーブルのデータセット
data_table,label_table,table = make_dataset_kai(y_table)
# Out:
# timesteps:20
# label_num:0

# %%
table
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.817637 -1.500119  1.357551  1.357551  1.357551  0.722514 -0.865078
# 1   -1.500119  1.357551  1.357551  1.357551  0.722514 -0.865078 -1.182600
# 2    1.357551  1.357551  1.357551  0.722514 -0.865078 -1.182600 -1.341359
# 3    1.357551  1.357551  0.722514 -0.865078 -1.182600 -1.341359 -1.500119
# 4    1.357551  0.722514 -0.865078 -1.182600 -1.341359 -1.500119 -1.500119
# ..        ...       ...       ...       ...       ...       ...       ...
# 975  1.516310  1.675069  1.675069  1.516310  1.675069  1.516310  1.516310
# 976  1.675069  1.675069  1.516310  1.675069  1.516310  1.516310  0.404995
# 977  1.675069  1.516310  1.675069  1.516310  1.516310  0.404995 -0.230041
# 978  1.516310  1.675069  1.516310  1.516310  0.404995 -0.230041  1.040032
# 979  1.675069  1.516310  1.516310  0.404995 -0.230041  1.040032  1.198791
#
#             7         8         9  ...        11        12        13  \
# 0   -1.182600 -1.341359 -1.500119  ... -1.500119 -1.341359 -1.500119
# 1   -1.341359 -1.500119 -1.500119  ... -1.341359 -1.500119 -0.865078
# 2   -1.500119 -1.500119 -1.500119  ... -1.500119 -0.865078 -1.182600
# 3   -1.500119 -1.500119 -1.341359  ... -0.865078 -1.182600 -0.865078
# 4   -1.500119 -1.341359 -1.500119  ... -1.182600 -0.865078 -0.706319
# ..        ...       ...       ...  ...       ...       ...       ...
# 975  0.404995 -0.230041  1.040032  ...  0.404995 -1.658878 -1.658878
# 976 -0.230041  1.040032  1.198791  ... -1.658878 -1.658878 -1.658878
# 977  1.040032  1.198791  0.404995  ... -1.658878 -1.658878 -2.770192
# 978  1.198791  0.404995 -1.658878  ... -1.658878 -2.770192 -2.770192
# 979  0.404995 -1.658878 -1.658878  ... -2.770192 -2.770192 -2.135155
#
#            14        15        16        17        18        19  LABEL
# 0   -0.865078 -1.182600 -0.865078 -0.706319 -0.865078  0.722514      0
# 1   -1.182600 -0.865078 -0.706319 -0.865078  0.722514  0.881273      0
# 2   -0.865078 -0.706319 -0.865078  0.722514  0.881273  0.881273      0
# 3   -0.706319 -0.865078  0.722514  0.881273  0.881273  1.040032      0
# 4   -0.865078  0.722514  0.881273  0.881273  1.040032  1.198791      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 975 -1.658878 -2.770192 -2.770192 -2.135155 -1.182600 -0.865078      0
# 976 -2.770192 -2.770192 -2.135155 -1.182600 -0.865078  0.404995      0
# 977 -2.770192 -2.135155 -1.182600 -0.865078  0.404995  0.881273      0
# 978 -2.135155 -1.182600 -0.865078  0.404995  0.881273  0.722514      0
# 979 -1.182600 -0.865078  0.404995  0.881273  0.722514  0.881273      0
#
# [980 rows x 21 columns]

# %%
#椅子のデータセット
data_isu,label_isu,isu = make_dataset_kai(y_isu)
# Out:
# timesteps:20
# label_num:1

# %%
#デニムのデータセット
data_denim,label_denim,denim = make_dataset_kai(y_denim)
# Out:
# timesteps:20
# label_num:2

# %%
#段ボールのデータセット
data_dan,label_dan,dan = make_dataset_kai(y_dan)
# Out:
# timesteps:20
# label_num:3

# %%
#ペットボトルのデータセット
data_petto,label_petto,petto = make_dataset_kai(y_petto)
# Out:
# timesteps:20
# label_num:4

# %%
#指のデータセット
data_yubi,label_yubi,yubi = make_dataset_kai(y_yubi)
# Out:
# timesteps:20
# label_num:5

# %% [markdown]
# ## 説明変数の作成

# %%
table
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.817637 -1.500119  1.357551  1.357551  1.357551  0.722514 -0.865078
# 1   -1.500119  1.357551  1.357551  1.357551  0.722514 -0.865078 -1.182600
# 2    1.357551  1.357551  1.357551  0.722514 -0.865078 -1.182600 -1.341359
# 3    1.357551  1.357551  0.722514 -0.865078 -1.182600 -1.341359 -1.500119
# 4    1.357551  0.722514 -0.865078 -1.182600 -1.341359 -1.500119 -1.500119
# ..        ...       ...       ...       ...       ...       ...       ...
# 975  1.516310  1.675069  1.675069  1.516310  1.675069  1.516310  1.516310
# 976  1.675069  1.675069  1.516310  1.675069  1.516310  1.516310  0.404995
# 977  1.675069  1.516310  1.675069  1.516310  1.516310  0.404995 -0.230041
# 978  1.516310  1.675069  1.516310  1.516310  0.404995 -0.230041  1.040032
# 979  1.675069  1.516310  1.516310  0.404995 -0.230041  1.040032  1.198791
#
#             7         8         9  ...        11        12        13  \
# 0   -1.182600 -1.341359 -1.500119  ... -1.500119 -1.341359 -1.500119
# 1   -1.341359 -1.500119 -1.500119  ... -1.341359 -1.500119 -0.865078
# 2   -1.500119 -1.500119 -1.500119  ... -1.500119 -0.865078 -1.182600
# 3   -1.500119 -1.500119 -1.341359  ... -0.865078 -1.182600 -0.865078
# 4   -1.500119 -1.341359 -1.500119  ... -1.182600 -0.865078 -0.706319
# ..        ...       ...       ...  ...       ...       ...       ...
# 975  0.404995 -0.230041  1.040032  ...  0.404995 -1.658878 -1.658878
# 976 -0.230041  1.040032  1.198791  ... -1.658878 -1.658878 -1.658878
# 977  1.040032  1.198791  0.404995  ... -1.658878 -1.658878 -2.770192
# 978  1.198791  0.404995 -1.658878  ... -1.658878 -2.770192 -2.770192
# 979  0.404995 -1.658878 -1.658878  ... -2.770192 -2.770192 -2.135155
#
#            14        15        16        17        18        19  LABEL
# 0   -0.865078 -1.182600 -0.865078 -0.706319 -0.865078  0.722514      0
# 1   -1.182600 -0.865078 -0.706319 -0.865078  0.722514  0.881273      0
# 2   -0.865078 -0.706319 -0.865078  0.722514  0.881273  0.881273      0
# 3   -0.706319 -0.865078  0.722514  0.881273  0.881273  1.040032      0
# 4   -0.865078  0.722514  0.881273  0.881273  1.040032  1.198791      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 975 -1.658878 -2.770192 -2.770192 -2.135155 -1.182600 -0.865078      0
# 976 -2.770192 -2.770192 -2.135155 -1.182600 -0.865078  0.404995      0
# 977 -2.770192 -2.135155 -1.182600 -0.865078  0.404995  0.881273      0
# 978 -2.135155 -1.182600 -0.865078  0.404995  0.881273  0.722514      0
# 979 -1.182600 -0.865078  0.404995  0.881273  0.722514  0.881273      0
#
# [980 rows x 21 columns]

# %%
concat = pd.concat([table,isu,dan,petto,denim,yubi])

# %%
concat
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.817637 -1.500119  1.357551  1.357551  1.357551  0.722514 -0.865078
# 1   -1.500119  1.357551  1.357551  1.357551  0.722514 -0.865078 -1.182600
# 2    1.357551  1.357551  1.357551  0.722514 -0.865078 -1.182600 -1.341359
# 3    1.357551  1.357551  0.722514 -0.865078 -1.182600 -1.341359 -1.500119
# 4    1.357551  0.722514 -0.865078 -1.182600 -1.341359 -1.500119 -1.500119
# ..        ...       ...       ...       ...       ...       ...       ...
# 975 -1.868333 -1.706545 -1.544757  1.043858  1.367435  0.234917  0.558494
# 976 -1.706545 -1.544757  1.043858  1.367435  0.234917  0.558494  1.691011
# 977 -1.544757  1.043858  1.367435  0.234917  0.558494  1.691011  1.691011
# 978  1.043858  1.367435  0.234917  0.558494  1.691011  1.691011  1.367435
# 979  1.367435  0.234917  0.558494  1.691011  1.691011  1.367435  0.396705
#
#             7         8         9  ...        11        12        13  \
# 0   -1.182600 -1.341359 -1.500119  ... -1.500119 -1.341359 -1.500119
# 1   -1.341359 -1.500119 -1.500119  ... -1.341359 -1.500119 -0.865078
# 2   -1.500119 -1.500119 -1.500119  ... -1.500119 -0.865078 -1.182600
# 3   -1.500119 -1.500119 -1.341359  ... -0.865078 -1.182600 -0.865078
# 4   -1.500119 -1.341359 -1.500119  ... -1.182600 -0.865078 -0.706319
# ..        ...       ...       ...  ...       ...       ...       ...
# 975  1.691011  1.691011  1.367435  ...  0.234917 -1.059388  0.882070
# 976  1.691011  1.367435  0.396705  ... -1.059388  0.882070  1.367435
# 977  1.367435  0.396705  0.234917  ...  0.882070  1.367435  1.529223
# 978  0.396705  0.234917 -1.059388  ...  1.367435  1.529223  0.396705
# 979  0.234917 -1.059388  0.882070  ...  1.529223  0.396705  1.043858
#
#            14        15        16        17        18        19  LABEL
# 0   -0.865078 -1.182600 -0.865078 -0.706319 -0.865078  0.722514      0
# 1   -1.182600 -0.865078 -0.706319 -0.865078  0.722514  0.881273      0
# 2   -0.865078 -0.706319 -0.865078  0.722514  0.881273  0.881273      0
# 3   -0.706319 -0.865078  0.722514  0.881273  0.881273  1.040032      0
# 4   -0.865078  0.722514  0.881273  0.881273  1.040032  1.198791      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 975  1.367435  1.529223  0.396705  1.043858  1.529223  1.367435      5
# 976  1.529223  0.396705  1.043858  1.529223  1.367435  0.234917      5
# 977  0.396705  1.043858  1.529223  1.367435  0.234917 -0.412236      5
# 978  1.043858  1.529223  1.367435  0.234917 -0.412236 -0.735812      5
# 979  1.529223  1.367435  0.234917 -0.412236 -0.735812 -0.412236      5
#
# [5880 rows x 21 columns]

# %%
concat.to_csv("2s_time.csv")

# %%
concat = pd.read_csv("2s_time.csv")

# %%
concat
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0 -1.817637 -1.500119  1.357550  1.357550  1.357550  0.722514
# 1              1 -1.500119  1.357550  1.357550  1.357550  0.722514 -0.865078
# 2              2  1.357550  1.357550  1.357550  0.722514 -0.865078 -1.182600
# 3              3  1.357550  1.357550  0.722514 -0.865078 -1.182600 -1.341359
# 4              4  1.357550  0.722514 -0.865078 -1.182600 -1.341359 -1.500119
# ...          ...       ...       ...       ...       ...       ...       ...
# 5875         975 -1.868333 -1.706545 -1.544757  1.043858  1.367434  0.234917
# 5876         976 -1.706545 -1.544757  1.043858  1.367434  0.234917  0.558494
# 5877         977 -1.544757  1.043858  1.367434  0.234917  0.558494  1.691011
# 5878         978  1.043858  1.367434  0.234917  0.558494  1.691011  1.691011
# 5879         979  1.367434  0.234917  0.558494  1.691011  1.691011  1.367434
#
#              6         7         8  ...        11        12        13  \
# 0    -0.865078 -1.182600 -1.341359  ... -1.500119 -1.341359 -1.500119
# 1    -1.182600 -1.341359 -1.500119  ... -1.341359 -1.500119 -0.865078
# 2    -1.341359 -1.500119 -1.500119  ... -1.500119 -0.865078 -1.182600
# 3    -1.500119 -1.500119 -1.500119  ... -0.865078 -1.182600 -0.865078
# 4    -1.500119 -1.500119 -1.341359  ... -1.182600 -0.865078 -0.706319
# ...        ...       ...       ...  ...       ...       ...       ...
# 5875  0.558494  1.691011  1.691011  ...  0.234917 -1.059388  0.882070
# 5876  1.691011  1.691011  1.367434  ... -1.059388  0.882070  1.367434
# 5877  1.691011  1.367434  0.396705  ...  0.882070  1.367434  1.529223
# 5878  1.367434  0.396705  0.234917  ...  1.367434  1.529223  0.396705
# 5879  0.396705  0.234917 -1.059388  ...  1.529223  0.396705  1.043858
#
#             14        15        16        17        18        19  LABEL
# 0    -0.865078 -1.182600 -0.865078 -0.706319 -0.865078  0.722514      0
# 1    -1.182600 -0.865078 -0.706319 -0.865078  0.722514  0.881273      0
# 2    -0.865078 -0.706319 -0.865078  0.722514  0.881273  0.881273      0
# 3    -0.706319 -0.865078  0.722514  0.881273  0.881273  1.040032      0
# 4    -0.865078  0.722514  0.881273  0.881273  1.040032  1.198791      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 5875  1.367434  1.529223  0.396705  1.043858  1.529223  1.367434      5
# 5876  1.529223  0.396705  1.043858  1.529223  1.367434  0.234917      5
# 5877  0.396705  1.043858  1.529223  1.367434  0.234917 -0.412236      5
# 5878  1.043858  1.529223  1.367434  0.234917 -0.412236 -0.735812      5
# 5879  1.529223  1.367434  0.234917 -0.412236 -0.735812 -0.412236      5
#
# [5880 rows x 22 columns]

# %% [markdown]
# # 説明変数の作成

# %%
#説明変数
ex = concat.iloc[:,1:-1]

# %%
ex
# Out:
# array([[[-1.817637  ],
#         [-1.5001186 ],
#         [ 1.3575505 ],
#         ...,
#         [-0.7063189 ],
#         [-0.8650781 ],
#         [ 0.72251374]],
#
#        [[-1.5001186 ],
#         [ 1.3575505 ],
#         [ 1.3575505 ],
#         ...,
#         [-0.8650781 ],
#         [ 0.72251374],
#         [ 0.881273  ]],
#
#        [[ 1.3575505 ],
#         [ 1.3575505 ],
#         [ 1.3575505 ],
#         ...,
#         [ 0.72251374],
#         [ 0.881273  ],
#         [ 0.881273  ]],
#
#        ...,
#
#        [[-1.5447569 ],
#         [ 1.043858  ],
#         [ 1.3674345 ],
#         ...,
#         [ 1.3674345 ],
#         [ 0.23491715],
#         [-0.41223565]],
#
#        [[ 1.043858  ],
#         [ 1.3674345 ],
#         [ 0.23491715],
#         ...,
#         [ 0.23491715],
#         [-0.41223565],
#         [-0.735812  ]],
#
#        [[ 1.3674345 ],
#         [ 0.23491715],
#         [ 0.55849355],
#         ...,
#         [-0.41223565],
#         [-0.735812  ],
#         [-0.41223565]]])

# %%
ex = np.array(ex)

# %%
ex.shape[0]
# Out:
# 5880

# %%
ex=ex.reshape(-1,20,1)

# %%
ex.shape
# Out:
# (5880, 20, 1)

# %% [markdown]
# ## ラベルデータの作成

# %%
label = concat.iloc[:,-1]

# %%
label = np.array(label)

# %%
label = label.reshape(-1,1)

# %%
label =one_hot(label)

# %%
label.shape
# Out:
# (5880, 6)

# %%
def make_data(concat):
    ex = concat.iloc[:,1:-1]
    ex = np.array(ex)
    ex=ex.reshape(-1,ex.shape[1],1)
    label = concat.iloc[:,-1]
    label = np.array(label)
    label = label.reshape(-1,1)
    label =one_hot(label)
    
    return ex,label

# %% [markdown]
# # トレーニングデータとテストデータに分割

# %%
X_train, X_test, Y_train, Y_test = split(ex,label)
# Out:
# シャッフルする:1 シャッフルしない:21
# testサイズを選んでください0.2

# %%
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# %% [markdown]
# # LSTMの実装

# %%
from tensorflow.keras.optimizers import RMSprop,Adam
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Bidirectional,LSTM,TimeDistributed

# %%
#むやみに層を増やすと逆に学習しなくなる
BATCHSIZE = 32
UNITNUM   = 128
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model = Sequential()
model.add(LSTM(256, input_shape = (X_train.shape[1], X_train.shape[2]), return_sequences = False))
model.add(Dropout(0.3))
# model.add(LSTM(128, return_sequences=True))
# model.add(Dropout(0.5))
# model.add(LSTM(128, return_sequences=False))
# model.add(Dropout(0.5))
model.add(Dense(6))
model.add(Activation("softmax"))
model.compile(loss = "categorical_crossentropy", optimizer = optimizer, metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 256)               264192
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 1542
# _________________________________________________________________
# activation_10 (Activation)   (None, 6)                 0
# =================================================================
# Total params: 265,734
# Trainable params: 265,734
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# model2 = Sequential()
# model2.add(Bidirectional(LSTM(32, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
# model2.add(Dropout(0.3))
# model2.add(Bidirectional(LSTM(32,return_sequences=False)))
# model2.add(Dropout(0.3))
# model2.add(Dense(6))
# model2.add(Activation('softmax'))
# model2.compile(loss='categorical_crossentropy', optimizer='rmsprop',metrics = ['accuracy'])
# model2.summary()

# %%
es = EarlyStopping(monitor='val_loss', patience=3, verbose=0, mode='auto')

# %%
history = model.fit(X_train, Y_train, batch_size=10, epochs=30,validation_split=0.2,callbacks=es)
# Out:
# Epoch 1/30
# 377/377 [==============================] - 6s 17ms/step - loss: 1.7310 - accuracy: 0.2259 - val_loss: 1.5414 - val_accuracy: 0.3369
# Epoch 2/30
# 377/377 [==============================] - 6s 15ms/step - loss: 1.4386 - accuracy: 0.3930 - val_loss: 1.3409 - val_accuracy: 0.4357
# Epoch 3/30
# 377/377 [==============================] - 6s 15ms/step - loss: 1.1523 - accuracy: 0.5137 - val_loss: 1.0870 - val_accuracy: 0.5345
# Epoch 4/30
# 377/377 [==============================] - 5s 15ms/step - loss: 0.9405 - accuracy: 0.6171 - val_loss: 0.8523 - val_accuracy: 0.6472
# Epoch 5/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.7730 - accuracy: 0.6909 - val_loss: 0.7091 - val_accuracy: 0.7258
# Epoch 6/30
# 377/377 [==============================] - 5s 14ms/step - loss: 0.6380 - accuracy: 0.7499 - val_loss: 0.6130 - val_accuracy: 0.7651
# Epoch 7/30
# 377/377 [==============================] - 5s 14ms/step - loss: 0.5210 - accuracy: 0.8026 - val_loss: 0.5419 - val_accuracy: 0.7779
# Epoch 8/30
# 377/377 [==============================] - 5s 14ms/step - loss: 0.4497 - accuracy: 0.8307 - val_loss: 0.4849 - val_accuracy: 0.8268
# Epoch 9/30
# 377/377 [==============================] - 5s 15ms/step - loss: 0.3663 - accuracy: 0.8642 - val_loss: 0.3490 - val_accuracy: 0.8767
# Epoch 10/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.3090 - accuracy: 0.8868 - val_loss: 0.4012 - val_accuracy: 0.8523
# Epoch 11/30
# 377/377 [==============================] - 6s 16ms/step - loss: 0.2677 - accuracy: 0.9062 - val_loss: 0.3624 - val_accuracy: 0.8565
# Epoch 12/30
# 377/377 [==============================] - 6s 16ms/step - loss: 0.2121 - accuracy: 0.9256 - val_loss: 0.2198 - val_accuracy: 0.9224
# Epoch 13/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.2168 - accuracy: 0.9259 - val_loss: 0.2501 - val_accuracy: 0.9150
# Epoch 14/30
# 377/377 [==============================] - 5s 15ms/step - loss: 0.1596 - accuracy: 0.9463 - val_loss: 0.2080 - val_accuracy: 0.9352
# Epoch 15/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.1374 - accuracy: 0.9546 - val_loss: 0.2223 - val_accuracy: 0.9192
# Epoch 16/30
# 377/377 [==============================] - 6s 16ms/step - loss: 0.1185 - accuracy: 0.9633 - val_loss: 0.2394 - val_accuracy: 0.9139
# Epoch 17/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.1154 - accuracy: 0.9615 - val_loss: 0.1873 - val_accuracy: 0.9299
# Epoch 18/30
# 377/377 [==============================] - 6s 16ms/step - loss: 0.0916 - accuracy: 0.9681 - val_loss: 0.1956 - val_accuracy: 0.9320
# Epoch 19/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.1076 - accuracy: 0.9647 - val_loss: 0.2443 - val_accuracy: 0.9097
# Epoch 20/30
# 377/377 [==============================] - 6s 16ms/step - loss: 0.0603 - accuracy: 0.9817 - val_loss: 0.1276 - val_accuracy: 0.9564
# Epoch 21/30
# 377/377 [==============================] - 6s 16ms/step - loss: 0.0724 - accuracy: 0.9769 - val_loss: 0.1349 - val_accuracy: 0.9532
# Epoch 22/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.0655 - accuracy: 0.9774 - val_loss: 0.0875 - val_accuracy: 0.9734
# Epoch 23/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.0566 - accuracy: 0.9830 - val_loss: 0.1988 - val_accuracy: 0.9341
# Epoch 24/30
# 377/377 [==============================] - 6s 15ms/step - loss: 0.0997 - accuracy: 0.9670 - val_loss: 0.1001 - val_accuracy: 0.9692
# Epoch 25/30
# 377/377 [==============================] - 5s 15ms/step - loss: 0.0756 - accuracy: 0.9748 - val_loss: 0.2039 - val_accuracy: 0.9309

# %% [markdown]
# # モデルの評価

# %% [markdown]
# ## lossとaccuracy

# %%
def plot_history(history):
    # model loss graph

    def plot_history_loss(fit):
        axL.plot(fit.history['loss'], label="loss for training")
        axL.plot(fit.history['val_loss'],label="loss for validation")
        axL.set_title('model loss')
        axL.set_xlabel('epoch')
        axL.set_ylabel('loss')
        axL.legend(loc='upper right')

    # model accuracy graph

    def plot_history_accuracy(fit):
        axR.plot(fit.history['accuracy'],
                 label="accuracy for training")
        axR.plot(fit.history['val_accuracy'],label="accuracy for validation")
        axR.set_title('model accuracy')
        axR.set_xlabel('epoch')
        axR.set_ylabel('accuracy')
        axR.legend(loc='lower right')

    ig, (axL, axR) = plt.subplots(ncols=2, figsize=(10, 5))
    plt.subplots_adjust(wspace=0.5)
    plot_history_loss(history)
    plot_history_accuracy(history)

# %%
plot_history(history)

# %%
model.save( "model20.h5" )

# %%
model.save_weights("model_weight20.h5")

# %% [markdown]
# ### テストデータでの精度

# %%
evaluate_model(model,X_test,Y_test)
# Out:
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1757 - accuracy: 0.9464
# loss: 0.17568841576576233 accuracy: 0.9464285969734192

# %% [markdown]
# ## 評価の可視化

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
pred = model.predict(X_test)

# %%
#予測データ
y_pred = np.argmax(pred,axis=1)

# %%
#正解データ
Y_acc = np.argmax(Y_test,axis=1)

# %%
class_names = ["table","chaIr","denim","cardboard","pettobottle","finger"]

# %%
cf_matrix = confusion_matrix(Y_acc, y_pred)
cd_df = pd.DataFrame(cf_matrix)

# %%
cd_df.columns=class_names
cd_df.index=class_names

# %%
plt.figure(figsize = (12,7))
sns.heatmap(cd_df.astype('float') / cd_df.sum(axis=1), annot=True, fmt='.2%' ,square = True,cmap='Reds')
plt.show()

# %% [markdown]
# # モデルの再利用と未知データの分類

# %%
#学習用データ
df_test_yubi = load("yubi2.csv")
df_test_table = load("table2.csv")
df_test_isu = load("isu2.csv")
df_test_petto = load("petto2.csv")
df_test_dan = load("dan2.csv")
df_test_denim = load("denim2.csv")

# %%
#学習用データ
x_test_yubi , y_test_yubi = get_xy(df_test_yubi)
x_test_table , y_test_table = get_xy(df_test_table)
x_test_denim , y_test_denim = get_xy(df_test_denim)
x_test_isu , y_test_isu = get_xy(df_test_isu)
x_test_dan , y_test_dan = get_xy(df_test_dan)
x_test_petto , y_test_petto = get_xy(df_test_petto)
# Out:
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data

# %%
#学習データに関して
#numpyに変換
y_test_yubi = np.array(y_test_yubi).reshape(-1,1)
y_test_table = np.array(y_test_table).reshape(-1,1)
y_test_denim = np.array(y_test_denim).reshape(-1,1)
y_test_isu = np.array(y_test_isu).reshape(-1,1)
y_test_dan = np.array(y_test_dan).reshape(-1,1)
y_test_petto = np.array(y_test_petto).reshape(-1,1)

# %%
#標準化
y_test_yubi = scale(y_test_yubi)
y_test_table = scale(y_test_table)
y_test_denim = scale(y_test_denim)
y_test_isu = scale(y_test_isu)
y_test_dan= scale(y_test_dan)
y_test_petto = scale(y_test_petto)

# %%
a,y_test_yubi = np.array(y_test_yubi)
b,y_test_table = np.array(y_test_table)
c,y_test_denim = np.array(y_test_denim)
d,y_test_isu = np.array(y_test_isu)
e,y_test_dan = np.array(y_test_dan)
f,y_test_petto = np.array(y_test_petto)
# Out:
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """
# /Users/ryusei/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
plt.figure(figsize=(12,4))
plt.plot((x+1)*0.09, y_test_yubi, color="b", label="finger")
plt.plot((x+1)*0.09, y_test_petto, label="pettobottle")
plt.plot((x+1)*0.09, y_test_dan, label="cardboard")
plt.plot((x+1)*0.09, y_test_denim, label="denim")
plt.plot((x+1)*0.09, y_test_isu, label="chair")
plt.plot((x+1)*0.09, y_test_table, label="table")
plt.xlim(0,15)
plt.ylim(-2.0,2.0)
plt.xlabel("time [ms]")
plt.ylabel("voltage [mV]")
plt.legend()
plt.show()

# %%
#テーブルのデータセット
data_table,label_table,table_test = make_dataset_kai(y_test_table)
# Out:
# timesteps:20
# label_num:0

# %%
#椅子のデータセット
data_isu,label_isu,isu_test = make_dataset_kai(y_test_isu)
# Out:
# timesteps:20
# label_num:1

# %%
#デニムのデータセット
data_denim,label_denim,denim_test = make_dataset_kai(y_test_denim)
# Out:
# timesteps:20
# label_num:2

# %%
#段ボールのデータセット
data_dan,label_dan,dan_test = make_dataset_kai(y_test_dan)
# Out:
# timesteps:20
# label_num:3

# %%
#ペットボトルのデータセット
data_petto,label_petto,petto_test = make_dataset_kai(y_test_petto)
# Out:
# timesteps:20
# label_num:4

# %%
#指のデータセット
data_yubi,label_yubi,yubi_test = make_dataset_kai(y_test_yubi)
# Out:
# timesteps:20
# label_num:5

# %%
concat_test = pd.concat([table_test,isu_test,dan_test,petto_test,denim_test,yubi_test])

# %%
concat_test.to_csv("test.csv")

# %%
test_data = pd.read_csv("test.csv")

# %%
test_data
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0  0.669921  1.099908  1.314902  1.314902  0.884915  0.669921
# 1              1  1.099908  1.314902  1.314902  0.884915  0.669921 -0.620042
# 2              2  1.314902  1.314902  0.884915  0.669921 -0.620042  0.239933
# 3              3  1.314902  0.884915  0.669921 -0.620042  0.239933  0.454927
# 4              4  0.884915  0.669921 -0.620042  0.239933  0.454927  0.454927
# ...          ...       ...       ...       ...       ...       ...       ...
# 5875         975 -1.123849 -1.558778 -2.428630 -0.833898 -0.543947  0.035954
# 5876         976 -1.558778 -2.428630 -0.833898 -0.543947  0.035954  0.325905
# 5877         977 -2.428630 -0.833898 -0.543947  0.035954  0.325905  0.325905
# 5878         978 -0.833898 -0.543947  0.035954  0.325905  0.325905  0.470881
# 5879         979 -0.543947  0.035954  0.325905  0.325905  0.470881 -1.413803
#
#              6         7         8  ...        11        12        13  \
# 0    -0.620042  0.239933  0.454927  ...  0.669921  0.454927  0.239933
# 1     0.239933  0.454927  0.454927  ...  0.454927  0.239933 -0.190054
# 2     0.454927  0.454927  0.454927  ...  0.239933 -0.190054 -0.620042
# 3     0.454927  0.454927  0.669921  ... -0.190054 -0.620042  0.239933
# 4     0.454927  0.669921  0.454927  ... -0.620042  0.239933 -1.910005
# ...        ...       ...       ...  ...       ...       ...       ...
# 5875  0.325905  0.325905  0.470881  ... -1.268824 -1.703754  0.035954
# 5876  0.325905  0.470881 -1.413803  ... -1.703754  0.035954  0.760831
# 5877  0.470881 -1.413803 -1.413803  ...  0.035954  0.760831  0.615856
# 5878 -1.413803 -1.413803 -1.268824  ...  0.760831  0.615856  0.760831
# 5879 -1.413803 -1.268824 -1.703754  ...  0.615856  0.760831 -1.558778
#
#             14        15        16        17        18        19  LABEL
# 0    -0.190054 -0.620042  0.239933 -1.910005 -2.339997 -0.835036      0
# 1    -0.620042  0.239933 -1.910005 -2.339997 -0.835036 -0.190054      0
# 2     0.239933 -1.910005 -2.339997 -0.835036 -0.190054  0.239933      0
# 3    -1.910005 -2.339997 -0.835036 -0.190054  0.239933  0.239933      0
# 4    -2.339997 -0.835036 -0.190054  0.239933  0.239933  0.454927      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 5875  0.760831  0.615856  0.760831 -1.558778 -1.123849 -1.558778      5
# 5876  0.615856  0.760831 -1.558778 -1.123849 -1.558778 -1.413803      5
# 5877  0.760831 -1.558778 -1.123849 -1.558778 -1.413803  0.325905      5
# 5878 -1.558778 -1.123849 -1.558778 -1.413803  0.325905  0.180930      5
# 5879 -1.123849 -1.558778 -1.413803  0.325905  0.180930 -0.543947      5
#
# [5880 rows x 22 columns]

# %%
a,b = make_data(test_data)

# %%
a.shape
# Out:
# (5880, 20, 1)

# %% [markdown]
# # データの集計

# %%
X_train_kai, X_test_kai, Y_train_kai, Y_test_kai = split(a,b)
# Out:
# シャッフルする:1 シャッフルしない:21
# testサイズを選んでください0.5

# %%
X_test_kai.shape
# Out:
# (2940, 20, 1)

# %%
Y_test_kai.shape
# Out:
# (2940, 6)

# %%
ls
# Out:
# 2s_time.csv                  model20.h5
# 6波形.csv                    model_weight.h5
# 6波形テスト.csv              model_weight20.h5
# 6波形ラベル.csv              modules/
# arduino.ipynb                pandas.ipynb
# arduino.py                   petto1.csv
# dan1.csv                     petto2.csv
# dan2.csv                     plan.drawio
# data解析.ipynb               python_vol/
# denim1.csv                   table1.csv
# denim2.csv                   table2.csv
# disny_sc.ipynb               test.csv
# isu1.csv                     yubi1.csv
# isu2.csv                     yubi2.csv
# lablab.ipynb                 研究条件めも
# lstm.ipynb                   時系列データ/
# model.h5                     データサイエンス/

# %%
model_recicle=load_model("model20.h5")
model_recicle.load_weights('model_weight20.h5')#作成したモデルが学習した重みを読み込み

# %%
#二回目の学習で格段に精度が上がっていることが確認できる。
history2 = model_recicle.fit(X_train_kai, Y_train_kai, batch_size=10, epochs=3,validation_split=0.2,callbacks=es)
# Out:
# Epoch 1/3
# 330/330 [==============================] - 5s 15ms/step - loss: 0.7726 - accuracy: 0.7257 - val_loss: 0.3918 - val_accuracy: 0.8617
# Epoch 2/3
#  60/330 [====>.........................] - ETA: 3s - loss: 0.4046 - accuracy: 0.8500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-168-08e5c23743f0> in <module>
#       1 #二回目の学習で格段に精度が上がっていることが確認できる。
# ----> 2 history2 = model_recicle.fit(X_train_kai, Y_train_kai, batch_size=10, epochs=3,validation_split=0.2,callbacks=es)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
evaluate_model(model_recicle,X_test_kai,Y_test_kai)
# Out:
# 92/92 [==============================] - 1s 7ms/step - loss: 2.9758 - accuracy: 0.4289
# loss: 2.9757745265960693 accuracy: 0.42891156673431396

# %%
y_pred_kai = model_recicle.predict(X_test_kai)

# %%
y_pred_kai = np.argmax(y_pred_kai,axis=1)
Y_acc_kai = np.argmax(Y_test_kai,axis=1)
cf_matrix_kai = confusion_matrix(Y_acc_kai, y_pred_kai)

# %%
cd_df_kai = pd.DataFrame(cf_matrix_kai)

# %%
cd_df_kai.columns=class_names
cd_df_kai.index=class_names

# %%
plt.figure(figsize = (12,7))
sns.heatmap(cd_df_kai.astype('float') / cd_df_kai.sum(axis=1), annot=True, fmt='.2%' ,square = True,cmap='Reds')
plt.show()

# %%
label_yubi = one_hot(label_yubi)

# %%
X_train_kai, X_test_kai, Y_train_kai, Y_test_kai = split(data_yubi,label_yubi)
# Out:
# シャッフルする:1 シャッフルしない:21
# testサイズを選んでください0.5

# %%
X_test_kai.shape
# Out:
# (490, 20, 1)

# %%
evaluate_model(model,X_test_kai,Y_test_kai)
# Out:
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5779 - accuracy: 0.7571
# loss: 0.5778810381889343 accuracy: 0.7571428418159485
