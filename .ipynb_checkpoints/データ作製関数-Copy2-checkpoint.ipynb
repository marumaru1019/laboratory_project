# %%
from modules.load import *
from modules.lstm import *
sns.set()
from tensorflow.keras.models import load_model

# %% [markdown]
# 0:テーブル
# 1:椅子
# 2:デニム
# 3:ダンボール
# 4:ペットボトル
# 5:指
# 6:マジックテープ
# 7:スポンジ
# 8:ガムテープ
# 9:タオル

# %% [markdown]
# # データの集計

# %%
#標準化前
def plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure(figsize=(12,4))
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(2.4, 2.8)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")
        
#標準化後
def standard_plot_g(title,x,y,start,end,save=False):
    #データの波形の確認の式
    #figureヲ宣言
    flg = plt.figure()
    flg = plt.title(title)
    #x:0スタートなので1を追加  1あたり0.09sなので情報を追加
    flg = plt.plot((x+1)*0.09, y)
    flg = plt.xlabel("time[s]")
    flg = plt.ylabel("Voltage[V]")          
    # 0-9秒
    flg = plt.xlim(start,end)
    # おおよそ2.3-2.5を推移
    flg = plt.ylim(-2.0, 2.0)
    flg = plt.show()
    if save ==True:
        name = input("名前を決めてください:")
        fig.savefig("img.png")

# %%
#学習用データ
df_yubi = load("finger1.csv")
df_table = load("tab1.csv")
df_isu = load("isuisu1.csv")
df_petto = load("pettobb1.csv")
df_dan = load("cardboard2.csv")
df_denim = load("denideni2.csv")
df_magic= load("magic1.csv")
df_gam = load("gamgam1.csv")
df_sponji = load("smonji3.csv")
df_taoru = load("taoru1.csv")

# %%
#データを纏める用に作製
df_list = [df_table,df_isu,df_denim,df_dan,df_petto,df_yubi,df_magic,df_sponji,df_gam,df_taoru]
data_col = ["table","chair","denim","cardboard" ,"pettobottle","finger","magic tape" ,"sponge","gum tape","taoru"]

# %%
#データセットの作製
k = []
for i in df_list:
    x,y = get_xy(i)
    k.append(y)
# Out:
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data
# data must have only figure data

# %%
#x軸用
x
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Name: Unnamed: 0, Length: 1000, dtype: int64

# %%
#ディクショナリー型のデータセットを作製　key:value = label:wave
df_dict = dict(zip(data_col,k))

# %%
df_dict
# Out:
# {'table': 0      2.73
#  1      2.73
#  2      2.73
#  3      2.73
#  4      2.73
#         ...
#  995    2.73
#  996    2.73
#  997    2.73
#  998    2.73
#  999    2.73
#  Name: 0, Length: 1000, dtype: float32,
#  'chair': 0      2.61
#  1      2.61
#  2      2.54
#  3      2.53
#  4      2.55
#         ...
#  995    2.65
#  996    2.60
#  997    2.58
#  998    2.55
#  999    2.61
#  Name: 0, Length: 1000, dtype: float32,
#  'denim': 0      2.62
#  1      2.62
#  2      2.64
#  3      2.64
#  4      2.64
#         ...
#  995    2.66
#  996    2.63
#  997    2.71
#  998    2.60
#  999    2.66
#  Name: 0, Length: 1000, dtype: float32,
#  'cardboard': 0      2.60
#  1      2.59
#  2      2.59
#  3      2.60
#  4      2.60
#         ...
#  995    2.71
#  996    2.71
#  997    2.71
#  998    2.71
#  999    2.71
#  Name: 0, Length: 1000, dtype: float32,
#  'pettobottle': 0      2.70
#  1      2.66
#  2      2.71
#  3      2.66
#  4      2.65
#         ...
#  995    2.67
#  996    2.68
#  997    2.67
#  998    2.59
#  999    2.63
#  Name: 0, Length: 1000, dtype: float32,
#  'finger': 0      2.61
#  1      2.62
#  2      2.62
#  3      2.56
#  4      2.57
#         ...
#  995    2.53
#  996    2.55
#  997    2.62
#  998    2.68
#  999    2.64
#  Name: 0, Length: 1000, dtype: float32,
#  'magic tape': 0      2.55
#  1      2.55
#  2      2.56
#  3      2.47
#  4      2.48
#         ...
#  995    2.59
#  996    2.57
#  997    2.57
#  998    2.59
#  999    2.59
#  Name: 0, Length: 1000, dtype: float32,
#  'sponge': 0      2.54
#  1      2.54
#  2      2.54
#  3      2.55
#  4      2.53
#         ...
#  995    2.55
#  996    2.54
#  997    2.54
#  998    2.54
#  999    2.54
#  Name: 0, Length: 1000, dtype: float32,
#  'gum tape': 0      2.76
#  1      2.75
#  2      2.75
#  3      2.76
#  4      2.76
#         ...
#  995    2.73
#  996    2.73
#  997    2.73
#  998    2.73
#  999    2.73
#  Name: 0, Length: 1000, dtype: float32,
#  'taoru': 0      2.52
#  1      2.54
#  2      2.47
#  3      2.52
#  4      2.45
#         ...
#  995    2.45
#  996    2.45
#  997    2.49
#  998    2.52
#  999    2.45
#  Name: 0, Length: 1000, dtype: float32}

# %%
def show_concat(df_dict):
    plt.figure(figsize=(12,4))
    for i in df_dict:
        plt.plot((x+1)*0.09, df_dict[i],  label=i)
    plt.xlim(0,8)
    plt.ylim(2.4,2.8)
    plt.xlabel("time [s]")
    plt.ylabel("voltage [V]")
    plt.legend()
    plt.show()

show_concat(df_dict)

# %% [markdown]
# # 標準化

# %%
#データの標準化の一括
share = []
def standard(df_dict,created_list=[]):
    for i in df_dict:
        y = np.array(df_dict[i]).reshape(-1,1)
        y = scale(y)
        a,y= np.array(y)
        y = np.array(y)
        created_list.append(y)
    return created_list

# %%
created_list = standard(df_dict,created_list=[])

# %%
created_list
# Out:
# [array([[ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [-0.09699166],
#         [ 0.26764017],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-0.8262553 ],
#         [-1.1908872 ],
#         [-1.1908872 ],
#         [-1.555519  ],
#         [-1.555519  ],
#         [-1.9201509 ],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.8262553 ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.46162346],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [-3.014055  ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-2.6494143 ],
#         [-3.014055  ],
#         [-2.6494143 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.014055  ],
#         [-3.014055  ],
#         [-3.014055  ],
#         [-3.014055  ],
#         [-3.014055  ],
#         [-0.8262553 ],
#         [ 0.26764017],
#         [-1.9201509 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.014055  ],
#         [-3.3786867 ],
#         [-3.014055  ],
#         [-3.3786867 ],
#         [-3.3786867 ],
#         [-3.7433186 ],
#         [-2.6494143 ],
#         [-2.6494143 ],
#         [-2.6494143 ],
#         [-3.014055  ],
#         [-2.6494143 ],
#         [-1.9201509 ],
#         [-1.9201509 ],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.8262553 ],
#         [-1.1908872 ],
#         [-0.8262553 ],
#         [-1.1908872 ],
#         [-0.8262553 ],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.8262553 ],
#         [-1.555519  ],
#         [-1.9201509 ],
#         [-1.555519  ],
#         [-1.555519  ],
#         [-1.1908872 ],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-1.1908872 ],
#         [-1.1908872 ],
#         [-1.1908872 ],
#         [-0.8262553 ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.46162346],
#         [-1.1908872 ],
#         [-1.1908872 ],
#         [-0.8262553 ],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.8262553 ],
#         [-1.1908872 ],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.46162346],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-1.1908872 ],
#         [-1.555519  ],
#         [-1.1908872 ],
#         [-1.9201509 ],
#         [-1.555519  ],
#         [-1.1908872 ],
#         [-1.1908872 ],
#         [-1.555519  ],
#         [-1.9201509 ],
#         [-1.9201509 ],
#         [-1.555519  ],
#         [-1.1908872 ],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [-0.8262553 ],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.8262553 ],
#         [-0.09699166],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.8262553 ],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.8262553 ],
#         [-0.8262553 ],
#         [-0.46162346],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-3.3786867 ],
#         [-0.8262553 ],
#         [ 0.26764017],
#         [ 1.7261674 ],
#         [ 1.7261674 ],
#         [ 1.7261674 ],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 1.7261674 ],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 1.7261674 ],
#         [ 1.7261674 ],
#         [ 1.7261674 ],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.46162346],
#         [-1.555519  ],
#         [-1.555519  ],
#         [-0.8262553 ],
#         [-0.46162346],
#         [-0.09699166],
#         [ 0.26764017],
#         [-0.46162346],
#         [-1.555519  ],
#         [-2.2847826 ],
#         [-1.9201509 ],
#         [-0.46162346],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 2.0907993 ],
#         [ 0.632272  ],
#         [-0.09699166],
#         [ 0.26764017],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.99690384],
#         [-0.46162346],
#         [-2.2847826 ],
#         [-3.3786867 ],
#         [-2.6494143 ],
#         [-1.9201509 ],
#         [-0.46162346],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-1.1908872 ],
#         [-2.6494143 ],
#         [-3.3786867 ],
#         [-2.6494143 ],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 1.3615357 ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-1.1908872 ],
#         [-1.9201509 ],
#         [-1.9201509 ],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [-0.09699166],
#         [-2.2847826 ],
#         [-1.9201509 ],
#         [-0.09699166],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.46162346],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [-1.9201509 ],
#         [-2.6494143 ],
#         [-1.555519  ],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [-0.46162346],
#         [-2.6494143 ],
#         [-1.9201509 ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.26764017],
#         [-0.09699166],
#         [-0.09699166],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 1.3615357 ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.632272  ],
#         [-0.09699166],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.26764017],
#         [ 0.632272  ],
#         [ 0.632272  ],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384],
#         [ 0.99690384]], dtype=float32),
#  array([[ 0.7886456 ],
#         [ 0.7886456 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [ 0.98704726],
#         [ 0.39184242],
#         [ 0.98704726],
#         [-0.6001656 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [ 0.7886456 ],
#         [ 0.7886456 ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [ 0.19344081],
#         [ 0.39184242],
#         [ 2.1774616 ],
#         [-1.3937721 ],
#         [-0.6001656 ],
#         [-0.0049608 ],
#         [ 0.98704726],
#         [ 2.1774616 ],
#         [ 1.1854535 ],
#         [-0.6001656 ],
#         [ 0.19344081],
#         [ 0.7886456 ],
#         [ 0.98704726],
#         [ 2.375863  ],
#         [-0.79856724],
#         [-0.79856724],
#         [ 2.1774616 ],
#         [-0.2033624 ],
#         [ 1.7806584 ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [ 0.7886456 ],
#         [ 2.1774616 ],
#         [ 1.7806584 ],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [ 0.7886456 ],
#         [ 0.98704726],
#         [ 1.7806584 ],
#         [ 1.3838551 ],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [ 0.7886456 ],
#         [ 1.7806584 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [ 0.7886456 ],
#         [ 0.59024405],
#         [ 0.7886456 ],
#         [-0.79856724],
#         [ 0.59024405],
#         [ 0.59024405],
#         [ 0.39184242],
#         [ 1.5822567 ],
#         [ 1.1854535 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [ 0.39184242],
#         [ 0.59024405],
#         [ 1.3838551 ],
#         [ 0.7886456 ],
#         [-0.79856724],
#         [-0.9969688 ],
#         [ 0.19344081],
#         [ 0.39184242],
#         [ 0.39184242],
#         [-1.5921737 ],
#         [-1.3937721 ],
#         [-1.3937721 ],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [-0.0049608 ],
#         [-0.79856724],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [ 0.7886456 ],
#         [ 0.19344081],
#         [-1.988977  ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [-0.401764  ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [ 0.7886456 ],
#         [ 0.98704726],
#         [ 0.39184242],
#         [-1.3937721 ],
#         [-0.401764  ],
#         [-0.0049608 ],
#         [ 0.19344081],
#         [ 0.19344081],
#         [ 0.39184242],
#         [-0.9969688 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [ 1.5822567 ],
#         [ 1.1854535 ],
#         [-1.3937721 ],
#         [-0.0049608 ],
#         [-0.401764  ],
#         [-0.401764  ],
#         [ 0.39184242],
#         [ 0.98704726],
#         [ 2.1774616 ],
#         [-0.0049608 ],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [-0.79856724],
#         [ 0.59024405],
#         [ 0.98704726],
#         [ 2.5742648 ],
#         [-1.1953704 ],
#         [-1.3937721 ],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [-0.401764  ],
#         [-1.3937721 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [ 1.9790599 ],
#         [ 0.98704726],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-1.3937721 ],
#         [-0.0049608 ],
#         [ 0.19344081],
#         [ 2.7726665 ],
#         [-1.1953704 ],
#         [-0.79856724],
#         [ 1.9790599 ],
#         [-0.79856724],
#         [-0.9969688 ],
#         [-1.5921737 ],
#         [-0.401764  ],
#         [-0.401764  ],
#         [ 0.98704726],
#         [ 1.3838551 ],
#         [-1.5921737 ],
#         [-1.5921737 ],
#         [-1.1953704 ],
#         [-1.3937721 ],
#         [-0.6001656 ],
#         [ 0.7886456 ],
#         [ 0.59024405],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [ 0.39184242],
#         [-0.79856724],
#         [-0.0049608 ],
#         [-1.3937721 ],
#         [-0.6001656 ],
#         [ 0.19344081],
#         [ 1.1854535 ],
#         [-0.79856724],
#         [-0.79856724],
#         [-0.6001656 ],
#         [-0.79856724],
#         [ 1.5822567 ],
#         [ 1.1854535 ],
#         [ 0.19344081],
#         [-0.401764  ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [-0.6001656 ],
#         [-0.0049608 ],
#         [-0.2033624 ],
#         [-1.1953704 ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [ 0.39184242],
#         [ 1.3838551 ],
#         [ 2.1774616 ],
#         [ 0.39184242],
#         [-0.9969688 ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [ 0.19344081],
#         [ 0.19344081],
#         [-0.6001656 ],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [ 0.39184242],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [ 0.7886456 ],
#         [ 0.59024405],
#         [-0.79856724],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [ 0.7886456 ],
#         [ 0.7886456 ],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [-0.79856724],
#         [ 0.39184242],
#         [ 0.59024405],
#         [ 1.7806584 ],
#         [-1.5921737 ],
#         [-0.401764  ],
#         [-0.79856724],
#         [ 1.9790599 ],
#         [ 2.375863  ],
#         [-0.0049608 ],
#         [-1.7905754 ],
#         [-0.79856724],
#         [-1.3937721 ],
#         [-0.401764  ],
#         [ 0.59024405],
#         [-1.1953704 ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [ 2.1774616 ],
#         [ 0.7886456 ],
#         [-1.1953704 ],
#         [-0.2033624 ],
#         [ 1.5822567 ],
#         [ 2.5742648 ],
#         [-0.9969688 ],
#         [-1.1953704 ],
#         [-0.2033624 ],
#         [ 1.3838551 ],
#         [ 1.5822567 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [ 0.7886456 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [ 0.39184242],
#         [ 2.1774616 ],
#         [ 1.5822567 ],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [ 0.7886456 ],
#         [ 2.5742648 ],
#         [-1.1953704 ],
#         [-1.1953704 ],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [ 0.98704726],
#         [ 0.39184242],
#         [-0.2033624 ],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [ 0.7886456 ],
#         [ 0.7886456 ],
#         [ 0.59024405],
#         [-0.0049608 ],
#         [-0.401764  ],
#         [-0.79856724],
#         [ 0.59024405],
#         [ 0.7886456 ],
#         [-1.1953704 ],
#         [-0.2033624 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [ 0.7886456 ],
#         [ 0.19344081],
#         [-0.79856724],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [ 1.3838551 ],
#         [-1.1953704 ],
#         [-0.79856724],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [ 1.3838551 ],
#         [ 0.98704726],
#         [ 0.59024405],
#         [-0.9969688 ],
#         [-1.3937721 ],
#         [-0.2033624 ],
#         [ 0.19344081],
#         [ 0.39184242],
#         [ 0.19344081],
#         [ 0.59024405],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [ 0.7886456 ],
#         [ 0.7886456 ],
#         [-0.79856724],
#         [-1.1953704 ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [-0.2033624 ],
#         [ 0.19344081],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [ 0.19344081],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [ 1.1854535 ],
#         [ 0.39184242],
#         [-0.2033624 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [ 0.98704726],
#         [-0.9969688 ],
#         [ 0.7886456 ],
#         [-1.3937721 ],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [ 1.1854535 ],
#         [ 0.39184242],
#         [ 0.98704726],
#         [ 0.7886456 ],
#         [-1.1953704 ],
#         [-0.2033624 ],
#         [ 0.19344081],
#         [-0.2033624 ],
#         [ 1.1854535 ],
#         [ 0.7886456 ],
#         [-1.3937721 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [ 0.98704726],
#         [ 0.39184242],
#         [ 0.39184242],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [ 0.19344081],
#         [ 0.98704726],
#         [ 0.98704726],
#         [-0.79856724],
#         [-1.1953704 ],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [ 1.3838551 ],
#         [ 1.1854535 ],
#         [ 0.7886456 ],
#         [ 0.39184242],
#         [-1.3937721 ],
#         [ 0.19344081],
#         [-0.0049608 ],
#         [ 1.3838551 ],
#         [ 0.98704726],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [ 0.39184242],
#         [-0.2033624 ],
#         [ 0.59024405],
#         [-0.79856724],
#         [-0.79856724],
#         [ 0.19344081],
#         [ 0.19344081],
#         [ 0.7886456 ],
#         [ 0.98704726],
#         [ 0.59024405],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [ 0.59024405],
#         [-0.401764  ],
#         [ 2.375863  ],
#         [ 0.98704726],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [ 0.39184242],
#         [ 0.19344081],
#         [ 0.59024405],
#         [-0.9969688 ],
#         [ 0.59024405],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [ 0.39184242],
#         [ 0.19344081],
#         [ 1.1854535 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [ 0.19344081],
#         [ 0.19344081],
#         [ 1.5822567 ],
#         [ 2.375863  ],
#         [ 2.375863  ],
#         [-1.1953704 ],
#         [ 0.7886456 ],
#         [ 0.19344081],
#         [ 0.59024405],
#         [ 1.1854535 ],
#         [ 0.98704726],
#         [ 0.98704726],
#         [-0.79856724],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [ 0.19344081],
#         [ 0.59024405],
#         [ 0.59024405],
#         [ 0.39184242],
#         [-1.3937721 ],
#         [-1.1953704 ],
#         [-0.0049608 ],
#         [ 0.7886456 ],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [ 0.19344081],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [ 1.1854535 ],
#         [ 1.5822567 ],
#         [ 0.98704726],
#         [-1.3937721 ],
#         [-0.79856724],
#         [-0.79856724],
#         [ 0.19344081],
#         [ 0.7886456 ],
#         [ 1.1854535 ],
#         [ 0.39184242],
#         [ 0.59024405],
#         [-1.5921737 ],
#         [-0.9969688 ],
#         [-1.3937721 ],
#         [ 0.39184242],
#         [ 0.59024405],
#         [ 0.19344081],
#         [-0.6001656 ],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [ 0.19344081],
#         [ 0.98704726],
#         [ 0.39184242],
#         [ 1.7806584 ],
#         [ 0.39184242],
#         [-0.79856724],
#         [-0.9969688 ],
#         [ 1.7806584 ],
#         [ 0.7886456 ],
#         [ 1.3838551 ],
#         [ 0.7886456 ],
#         [-1.7905754 ],
#         [-0.6001656 ],
#         [ 0.19344081],
#         [ 0.7886456 ],
#         [ 0.39184242],
#         [ 0.19344081],
#         [-0.0049608 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [ 0.59024405],
#         [ 0.7886456 ],
#         [ 1.9790599 ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [ 1.3838551 ],
#         [-0.401764  ],
#         [ 0.19344081],
#         [ 1.7806584 ],
#         [ 1.1854535 ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [ 1.1854535 ],
#         [-0.0049608 ],
#         [ 0.7886456 ],
#         [-1.1953704 ],
#         [-0.401764  ],
#         [ 0.19344081],
#         [ 1.9790599 ],
#         [ 1.1854535 ],
#         [ 0.39184242],
#         [ 1.1854535 ],
#         [-1.7905754 ],
#         [-0.9969688 ],
#         [ 0.19344081],
#         [ 2.375863  ],
#         [-0.9969688 ],
#         [ 0.59024405],
#         [-1.3937721 ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [-0.0049608 ],
#         [-0.2033624 ],
#         [ 0.39184242],
#         [ 0.98704726],
#         [-1.1953704 ],
#         [-1.1953704 ],
#         [-0.79856724],
#         [ 0.7886456 ],
#         [ 0.7886456 ],
#         [ 1.9790599 ],
#         [ 1.1854535 ],
#         [-1.1953704 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [ 0.19344081],
#         [ 0.59024405],
#         [ 0.59024405],
#         [-1.5921737 ],
#         [-1.1953704 ],
#         [ 0.19344081],
#         [ 0.59024405],
#         [ 1.3838551 ],
#         [-1.1953704 ],
#         [ 1.7806584 ],
#         [-1.5921737 ],
#         [-0.79856724],
#         [-0.2033624 ],
#         [-0.2033624 ],
#         [-0.2033624 ],
#         [-0.0049608 ],
#         [-1.7905754 ],
#         [-0.9969688 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [-1.7905754 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.79856724],
#         [-0.6001656 ],
#         [ 0.39184242],
#         [-0.401764  ],
#         [-1.3937721 ],
#         [ 0.39184242],
#         [-0.9969688 ],
#         [-0.79856724],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [ 0.59024405],
#         [-1.5921737 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.79856724],
#         [ 0.19344081],
#         [-0.9969688 ],
#         [-1.3937721 ],
#         [-1.1953704 ],
#         [-0.79856724],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [-1.5921737 ],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [-0.0049608 ],
#         [-0.2033624 ],
#         [-0.2033624 ],
#         [-0.79856724],
#         [-1.5921737 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [-0.6001656 ],
#         [ 0.19344081],
#         [-0.0049608 ],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-1.7905754 ],
#         [-1.1953704 ],
#         [-1.1953704 ],
#         [-0.2033624 ],
#         [-0.79856724],
#         [-1.1953704 ],
#         [-0.401764  ],
#         [-1.5921737 ],
#         [-1.1953704 ],
#         [-1.1953704 ],
#         [ 0.39184242],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [ 0.39184242],
#         [-0.2033624 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [-0.79856724],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [-0.0049608 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [-0.2033624 ],
#         [ 0.98704726],
#         [ 1.5822567 ],
#         [-0.6001656 ],
#         [-1.5921737 ],
#         [-1.1953704 ],
#         [-0.2033624 ],
#         [-0.9969688 ],
#         [ 1.1854535 ],
#         [-1.7905754 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.0049608 ],
#         [-0.2033624 ],
#         [ 1.5822567 ],
#         [-1.5921737 ],
#         [-1.5921737 ],
#         [-0.401764  ],
#         [-0.79856724],
#         [ 0.39184242],
#         [ 1.3838551 ],
#         [ 0.59024405],
#         [-0.79856724],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [-0.0049608 ],
#         [-0.2033624 ],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [ 0.59024405],
#         [ 0.7886456 ],
#         [-1.3937721 ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [ 0.19344081],
#         [ 1.5822567 ],
#         [-0.0049608 ],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [ 2.5742648 ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [ 1.3838551 ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [-1.3937721 ],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [-0.2033624 ],
#         [-1.1953704 ],
#         [-1.3937721 ],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [ 0.19344081],
#         [ 0.7886456 ],
#         [-0.9969688 ],
#         [-0.79856724],
#         [-0.79856724],
#         [-0.0049608 ],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [-0.2033624 ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [ 1.9790599 ],
#         [-0.2033624 ],
#         [ 1.3838551 ],
#         [-0.6001656 ],
#         [-0.2033624 ],
#         [-0.0049608 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [ 1.5822567 ],
#         [-1.3937721 ],
#         [-0.79856724],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.9969688 ],
#         [ 1.7806584 ],
#         [-0.2033624 ],
#         [-1.1953704 ],
#         [-0.401764  ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.0049608 ],
#         [-0.79856724],
#         [-0.79856724],
#         [ 1.3838551 ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [ 0.19344081],
#         [-0.9969688 ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [ 0.59024405],
#         [-0.79856724],
#         [ 0.7886456 ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-0.0049608 ],
#         [-0.9969688 ],
#         [ 1.3838551 ],
#         [ 2.5742648 ],
#         [-0.9969688 ],
#         [-1.3937721 ],
#         [-1.1953704 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [ 0.98704726],
#         [-1.3937721 ],
#         [-1.7905754 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [-0.0049608 ],
#         [-0.6001656 ],
#         [ 0.98704726],
#         [ 2.5742648 ],
#         [-1.1953704 ],
#         [ 0.7886456 ],
#         [ 0.59024405],
#         [-0.401764  ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [-1.1953704 ],
#         [-1.7905754 ],
#         [-1.1953704 ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [-0.401764  ],
#         [ 0.7886456 ],
#         [-0.79856724],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [ 1.1854535 ],
#         [ 0.59024405],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [ 0.7886456 ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [-1.1953704 ],
#         [-0.6001656 ],
#         [ 0.59024405],
#         [ 2.1774616 ],
#         [ 1.5822567 ],
#         [-0.2033624 ],
#         [ 1.9790599 ],
#         [-0.9969688 ],
#         [-0.0049608 ],
#         [ 1.5822567 ],
#         [-0.9969688 ],
#         [-0.9969688 ],
#         [-0.2033624 ],
#         [-0.6001656 ],
#         [-0.79856724],
#         [ 0.98704726],
#         [ 1.5822567 ],
#         [ 1.1854535 ],
#         [ 0.98704726],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [ 2.1774616 ],
#         [ 2.1774616 ],
#         [ 2.375863  ],
#         [ 1.9790599 ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [ 0.19344081],
#         [ 0.39184242],
#         [ 1.7806584 ],
#         [-0.9969688 ],
#         [ 0.98704726],
#         [ 0.19344081],
#         [-0.79856724],
#         [ 1.7806584 ],
#         [ 0.98704726],
#         [ 0.98704726],
#         [-0.0049608 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [-0.6001656 ],
#         [ 1.5822567 ],
#         [ 0.7886456 ],
#         [ 1.9790599 ],
#         [ 2.1774616 ],
#         [-0.401764  ],
#         [-0.79856724],
#         [-0.9969688 ],
#         [ 1.1854535 ],
#         [ 1.5822567 ],
#         [ 0.19344081],
#         [-1.3937721 ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [ 0.39184242],
#         [ 1.1854535 ],
#         [ 1.7806584 ],
#         [ 0.39184242],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [ 1.1854535 ],
#         [ 0.98704726],
#         [ 1.7806584 ],
#         [ 1.7806584 ],
#         [ 0.59024405],
#         [-0.6001656 ],
#         [-0.9969688 ],
#         [ 1.3838551 ],
#         [ 1.9790599 ],
#         [ 1.7806584 ],
#         [ 0.59024405],
#         [-0.6001656 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [ 0.7886456 ],
#         [ 1.9790599 ],
#         [ 2.375863  ],
#         [-0.401764  ],
#         [-0.401764  ],
#         [-0.79856724],
#         [ 0.39184242],
#         [ 1.7806584 ],
#         [ 1.5822567 ],
#         [ 1.9790599 ],
#         [-0.79856724],
#         [-0.401764  ],
#         [ 0.39184242],
#         [ 1.5822567 ],
#         [ 2.5742648 ],
#         [-0.0049608 ],
#         [-0.0049608 ],
#         [-0.401764  ],
#         [-0.79856724],
#         [ 1.5822567 ],
#         [ 0.19344081],
#         [ 1.1854535 ],
#         [ 1.3838551 ],
#         [-0.6001656 ],
#         [-0.401764  ],
#         [-1.3937721 ],
#         [ 1.1854535 ],
#         [ 0.98704726],
#         [ 1.5822567 ],
#         [ 0.59024405],
#         [-0.401764  ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [ 1.1854535 ],
#         [ 1.3838551 ],
#         [ 1.9790599 ],
#         [ 0.7886456 ],
#         [-0.401764  ],
#         [-0.401764  ],
#         [ 1.3838551 ],
#         [ 0.59024405],
#         [ 0.98704726],
#         [ 1.1854535 ],
#         [-0.2033624 ],
#         [-0.6001656 ],
#         [-0.0049608 ],
#         [ 1.7806584 ],
#         [ 2.1774616 ],
#         [-0.2033624 ],
#         [ 1.7806584 ],
#         [-0.2033624 ],
#         [-0.6001656 ],
#         [ 0.39184242],
#         [ 1.1854535 ],
#         [ 1.3838551 ],
#         [ 0.98704726],
#         [-0.401764  ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [ 1.3838551 ],
#         [ 1.7806584 ],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [-0.9969688 ],
#         [-0.6001656 ],
#         [ 0.98704726],
#         [ 1.3838551 ],
#         [ 0.59024405],
#         [ 0.39184242],
#         [-0.2033624 ],
#         [-0.79856724],
#         [ 1.1854535 ],
#         [ 0.98704726],
#         [ 1.1854535 ],
#         [-0.0049608 ],
#         [ 2.7726665 ],
#         [-0.401764  ],
#         [-1.1953704 ],
#         [ 2.1774616 ],
#         [ 0.98704726],
#         [ 0.19344081],
#         [ 0.59024405],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [ 1.1854535 ],
#         [ 2.1774616 ],
#         [ 1.5822567 ],
#         [ 1.9790599 ],
#         [ 2.1774616 ],
#         [-0.6001656 ],
#         [ 0.39184242],
#         [-0.2033624 ],
#         [ 1.3838551 ],
#         [ 1.5822567 ],
#         [ 3.3678713 ],
#         [-0.401764  ],
#         [-0.2033624 ],
#         [ 1.5822567 ],
#         [ 1.1854535 ],
#         [ 1.5822567 ],
#         [-0.2033624 ],
#         [-0.401764  ],
#         [-0.79856724],
#         [ 0.59024405],
#         [ 0.19344081],
#         [ 0.7886456 ],
#         [-0.0049608 ],
#         [ 0.39184242],
#         [-0.6001656 ],
#         [ 1.5822567 ],
#         [ 1.1854535 ],
#         [ 1.9790599 ],
#         [ 1.3838551 ],
#         [-0.401764  ],
#         [ 0.98704726],
#         [ 0.39184242],
#         [ 1.3838551 ],
#         [ 1.5822567 ],
#         [-0.401764  ],
#         [-0.401764  ],
#         [-0.6001656 ],
#         [ 1.3838551 ],
#         [ 1.5822567 ],
#         [ 0.59024405],
#         [ 0.19344081],
#         [-0.401764  ],
#         [ 0.7886456 ]], dtype=float32),
#  array([[-1.1977806 ],
#         [-1.1977806 ],
#         [-0.80557674],
#         [-0.80557674],
#         [-0.80557674],
#         [-1.0016763 ],
#         [-0.80557674],
#         [-1.982179  ],
#         [-0.80557674],
#         [-0.60947704],
#         [-0.21727782],
#         [-1.0016763 ],
#         [-1.0016763 ],
#         [-1.0016763 ],
#         [-0.41337743],
#         [-0.21727782],
#         [-0.02117822],
#         [-0.21727782],
#         [-0.41337743],
#         [-0.21727782],
#         [-1.0016763 ],
#         [-0.02117822],
#         [-0.02117822],
#         [-0.02117822],
#         [-0.41337743],
#         [-0.21727782],
#         [-0.80557674],
#         [-0.41337743],
#         [-0.21727782],
#         [-0.02117822],
#         [-0.41337743],
#         [-0.21727782],
#         [-0.02117822],
#         [-1.5899798 ],
#         [-0.21727782],
#         [-0.21727782],
#         [-0.02117822],
#         [-1.0016763 ],
#         [-0.60947704],
#         [-0.80557674],
#         [-1.7860794 ],
#         [-0.02117822],
#         [-0.02117822],
#         [-0.21727782],
#         [-0.02117822],
#         [-0.60947704],
#         [-1.1977806 ],
#         [-0.41337743],
#         [-0.41337743],
#         [-0.21727782],
#         [-0.60947704],
#         [-0.41337743],
#         [-0.60947704],
#         [-1.1977806 ],
#         [-1.0016763 ],
#         [-0.60947704],
#         [-0.02117822],
#         [-0.21727782],
#         [-0.21727782],
#         [-0.41337743],
#         [-1.0016763 ],
#         [-0.60947704],
#         [ 0.17492141],
#         [ 0.17492141],
#         [-0.21727782],
#         [-0.02117822],
#         [ 0.17492141],
#         [-1.1977806 ],
#         [-0.41337743],
#         [-0.02117822],
#         [-0.02117822],
#         [-0.02117822],
#         [ 0.17492141],
#         [-0.60947704],
#         [-1.0016763 ],
#         [-0.02117822],
#         [ 0.17492141],
#         [ 0.17492141],
#         [ 0.37102103],
#         [-0.41337743],
#         [-0.21727782],
#         [-1.1977806 ],
#         [-0.41337743],
#         [-0.02117822],
#         [-0.02117822],
# ...
#         [ 1.5873154 ],
#         [ 2.9391425 ],
#         [ 4.8317075 ],
#         [ 5.6428037 ],
#         [ 0.77621907],
#         [-0.03487718],
#         [ 1.0465845 ],
#         [-0.5756081 ],
#         [ 1.0465845 ],
#         [ 3.209508  ],
#         [-0.5756081 ],
#         [ 0.77621907],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [ 0.23548825],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 2.9391425 ],
#         [-0.03487718],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [-0.03487718],
#         [-0.5756081 ],
#         [ 1.31695   ],
#         [-0.3052426 ],
#         [-0.3052426 ],
#         [ 0.23548825],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.03487718],
#         [ 1.31695   ],
#         [-0.5756081 ],
#         [ 0.77621907],
#         [ 0.77621907],
#         [-0.5756081 ],
#         [ 0.23548825],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [-0.03487718],
#         [-0.03487718],
#         [ 1.0465845 ],
#         [ 1.5873154 ],
#         [-0.3052426 ],
#         [ 1.31695   ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 0.77621907],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 1.8576808 ],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [ 0.77621907],
#         [-0.3052426 ],
#         [ 2.1280463 ],
#         [ 0.23548825],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 0.50585365],
#         [-0.5756081 ],
#         [ 1.0465845 ],
#         [-0.3052426 ],
#         [ 1.31695   ],
#         [ 2.1280463 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [ 1.31695   ],
#         [-0.5756081 ],
#         [ 0.77621907],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 0.23548825],
#         [-0.5756081 ],
#         [ 2.1280463 ],
#         [ 0.50585365],
#         [-0.5756081 ],
#         [ 1.0465845 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 0.50585365],
#         [ 1.0465845 ],
#         [-0.8459735 ],
#         [ 0.50585365],
#         [-0.8459735 ],
#         [ 1.31695   ],
#         [-0.5756081 ],
#         [ 1.5873154 ],
#         [-0.03487718],
#         [-0.8459735 ],
#         [-0.5756081 ],
#         [-0.8459735 ],
#         [-0.3052426 ],
#         [ 1.0465845 ],
#         [-0.5756081 ],
#         [-0.8459735 ],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [ 2.1280463 ],
#         [ 3.209508  ],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [ 0.23548825],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [ 0.23548825],
#         [ 1.31695   ],
#         [-0.5756081 ],
#         [ 1.31695   ],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 0.23548825],
#         [-0.8459735 ],
#         [ 0.23548825],
#         [ 0.23548825],
#         [-0.8459735 ],
#         [-0.5756081 ],
#         [-0.5756081 ],
#         [ 1.0465845 ],
#         [ 1.8576808 ],
#         [-0.8459735 ],
#         [-0.3052426 ],
#         [ 0.50585365],
#         [ 1.31695   ],
#         [ 0.77621907],
#         [ 0.77621907],
#         [-0.8459735 ],
#         [-0.03487718],
#         [ 1.5873154 ],
#         [-0.8459735 ],
#         [ 2.1280463 ],
#         [ 0.50585365],
#         [ 0.23548825],
#         [ 1.0465845 ],
#         [ 1.0465845 ],
#         [ 1.0465845 ],
#         [ 1.31695   ],
#         [-0.8459735 ],
#         [-0.5756081 ],
#         [ 1.0465845 ],
#         [-0.8459735 ],
#         [ 1.0465845 ],
#         [ 0.77621907],
#         [-0.8459735 ],
#         [ 1.31695   ],
#         [ 0.77621907],
#         [-0.03487718],
#         [ 1.31695   ],
#         [ 1.0465845 ],
#         [-0.8459735 ],
#         [ 0.77621907],
#         [ 0.23548825],
#         [-0.8459735 ],
#         [ 0.23548825],
#         [-0.8459735 ],
#         [-0.03487718],
#         [-0.03487718],
#         [-0.8459735 ],
#         [ 1.31695   ],
#         [ 0.50585365],
#         [-0.8459735 ],
#         [-0.8459735 ],
#         [-0.3052426 ],
#         [-0.5756081 ],
#         [ 0.77621907],
#         [ 1.0465845 ],
#         [-0.8459735 ],
#         [-0.8459735 ],
#         [-0.3052426 ],
#         [-0.8459735 ],
#         [-0.5756081 ],
#         [ 3.209508  ],
#         [-0.8459735 ],
#         [-0.5756081 ],
#         [-0.8459735 ],
#         [-0.5756081 ],
#         [

#         [-1.116339  ],
#         [-1.116339  ],
#         [-1.116339  ],
#         [-0.03487718],
#         [ 0.77621907],
#         [-1.116339  ]], dtype=float32)]

# %%
#ディクショナリー型のデータセットを作製　key:value = label:wave
df_dict_std = dict(zip(data_col, created_list))

# %%
def show_concat_std(df_dict_std):
    plt.figure(figsize=(12,4))
    for i in df_dict:
        plt.plot((x+1)*0.09, df_dict_std[i],  label=i)
    plt.xlim(0,8)
    plt.ylim(-2,2)
    plt.xlabel("time [s]")
    plt.ylabel("voltage_std [V]")
    plt.legend()
    plt.show()

show_concat_std(df_dict_std)

# %% [markdown]
# # DataSetの合成

# %%
#名前をラベルにしたDataSet
def make_dataset_name(time_steps,df_dict):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(len(df_dict[i])-maxlen):
            data.append(df_dict[i][j:j + maxlen])
            target.append(i)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z


#ラベルを数値にしたDataSet
def make_dataset(time_steps,df_dict):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(len(df_dict[i])-maxlen):
            data.append(df_dict[i][j:j + maxlen])
            target.append(h)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z


#ラベルを数値にしたDataSet ストライド付き
def make_dataset_stride(time_steps,df_dict,stride):
    x, y, z =[],[],[]
    h=0
    for i in df_dict:
        data, target = [], []
        maxlen = time_steps

        for j in range(int((len(df_dict[i])-maxlen)/int(stride))):
            data.append(df_dict[i][j*stride:j*stride + maxlen])
            target.append(h)

        re_data = np.array(data).reshape(len(data), maxlen,1 )
        re_target = np.array(target).reshape(len(data), 1)
        csv_data = np.array(data).reshape(len(data), maxlen)
        csv_data=pd.DataFrame(csv_data)
        csv_data["LABEL"] =re_target
        h+=1
        x.append(re_data)
        y.append(re_target)
        z.append(csv_data)
        

    return x,y,z

# %%
x,y,z=make_dataset(20,df_dict_std)

# %%
xx,yy,zz=make_dataset_stride(20,df_dict_std,3)

# %%
zz[0].shape
# Out:
# (326, 21)

# %%
zz[0]
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 1    0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 2    0.996904  0.996904  0.996904  0.996904  0.996904 -0.096992  0.267640
# 3    0.996904  0.996904 -0.096992  0.267640  0.267640  0.267640  0.267640
# 4    0.267640  0.267640  0.267640  0.267640  0.267640  0.267640  0.267640
# ..        ...       ...       ...       ...       ...       ...       ...
# 321  0.267640  0.267640  0.632272  0.632272  0.996904  0.632272 -0.096992
# 322  0.632272  0.996904  0.632272 -0.096992  0.267640  0.267640  0.267640
# 323 -0.096992  0.267640  0.267640  0.267640  0.267640  0.267640  0.267640
# 324  0.267640  0.267640  0.267640  0.267640  0.267640  0.267640  0.267640
# 325  0.267640  0.267640  0.267640  0.267640  0.267640  0.267640  0.267640
#
#             7         8         9  ...        11       12        13        14  \
# 0    0.996904  0.996904  0.996904  ... -0.096992  0.26764  0.267640  0.267640
# 1    0.996904 -0.096992  0.267640  ...  0.267640  0.26764  0.267640  0.267640
# 2    0.267640  0.267640  0.267640  ...  0.267640  0.26764  0.267640  0.267640
# 3    0.267640  0.267640  0.267640  ...  0.267640  0.26764  0.267640  0.267640
# 4    0.267640  0.267640  0.267640  ...  0.267640  0.26764  0.267640  0.267640
# ..        ...       ...       ...  ...       ...      ...       ...       ...
# 321  0.267640  0.267640  0.267640  ...  0.267640  0.26764  0.267640  0.267640
# 322  0.267640  0.267640  0.267640  ...  0.267640  0.26764  0
1
# ..        ...       ...       ...       ...       ...       ...    ...
# 975  1.383855  1.582257 -0.401764 -0.401764 -0.600166  1.383855      1
# 976  1.582257 -0.401764 -0.401764 -0.600166  1.383855  1.582257      1
# 977 -0.401764 -0.401764 -0.600166  1.383855  1.582257  0.590244      1
# 978 -0.401764 -0.600166  1.383855  1.582257  0.590244  0.193441      1
# 979 -0.600166  1.383855  1.582257  0.590244  0.193441 -0.401764      1
#
# [980 rows x 21 columns]

# %% [markdown]
# # 再利用可能なようにcsvファイルとして登録

# %%
con = pd.DataFrame(index=[], columns=[])

# %%
def make_csv(name,dataset,data_col,save_data=False):
    con = pd.DataFrame(index=[], columns=[])
    for i,j in enumerate(dataset):
        #save_dataをTrueにすると作製
        con=pd.concat([con,j])
        if save_data:
            j.to_csv("{}{}.csv".format(data_col[i],name))
    return con

# %%
conm = make_csv("テストだよ",zz,data_col)

# %%
conm
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 1    0.996904  0.996904  0.996904  0.996904  0.996904  0.996904  0.996904
# 2    0.996904  0.996904  0.996904  0.996904  0.996904 -0.096992  0.267640
# 3    0.996904  0.996904 -0.096992  0.267640  0.267640  0.267640  0.267640
# 4    0.267640  0.267640  0.267640  0.267640  0.267640  0.267640  0.267640
# ..        ...       ...       ...       ...       ...       ...       ...
# 321 -0.305243 -0.845973 -0.575608  0.235488 -1.116339  1.587315 -0.034877
# 322  0.235488 -1.116339  1.587315 -0.034877 -1.116339 -0.845973 -0.845973
# 323 -0.034877 -1.116339 -0.845973 -0.845973  1.857681  1.046584 -0.305243
# 324 -0.845973  1.857681  1.046584 -0.305243 -1.116339 -0.575608  0.505854
# 325 -0.305243 -1.116339 -0.575608  0.505854 -1.116339 -0.305243 -0.845973
#
#             7         8         9  ...        11        12        13  \
# 0    0.996904  0.996904  0.996904  ... -0.096992  0.267640  0.267640
# 1    0.996904 -0.096992  0.267640  ...  0.267640  0.267640  0.267640
# 2    0.267640  0.267640  0.267640  ...  0.267640  0.267640  0.267640
# 3    0.267640  0.267640  0.267640  ...  0.267640  0.267640  0.267640
# 4    0.267640  0.267640  0.267640  ...  0.267640  0.267640  0.267640
# ..        ...       ...       ...  ...       ...       ...       ...
# 321 -1.116339 -0.845973 -0.845973  ...  1.046584 -0.305243 -1.116339
# 322  1.857681  1.046584 -0.305243  ... -0.575608  0.505854 -1.116339
# 323 -1.116339 -0.575608  0.505854  ... -0.305243 -0.845973 -1.116339
# 324 -1.116339 -0.305243 -0.845973  ... -1.116339 -1.116339  0.505854
# 325 -1.116339 -1.116339 -1.116339  ... -1.116339 -0.305243 -0.845973
#
#            14        15        16        17        18        19  LABEL
# 0    0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 1    0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 2    0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 3    0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# 4    0.267640  0.267640  0.267640  0.267640  0.267640  0.267640      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 321 -0.575608  0.505854 -1.116339 -0.305243 -0.845973 -1.116339      9
# 322 -0.305243 -0.845973 -1.116339 -1.116339 -1.116339  0.505854      9
# 323 -1.116339 -1.116339  0.505854 -1.116339 -0.305243 -0.845973      9
# 324 -1.116339 -0.305243 -0.845973 -1.116339 -0.575608  0.235488      9
# 325 -1.116339 -0.575608  0.235488 -1.116339  0.776219 -1.116339      9
#
# [3260 rows x 21 columns]

# %%
def make_data(concat):
    ex = concat.iloc[:,:-1]
    ex = np.array(ex)
    ex=ex.reshape(-1,ex.shape[1],1)
    label = concat.iloc[:,-1]
    label = np.array(label)
    label = label.reshape(-1,1)
    label =one_hot(label)
    
    return ex,label

ex,label = make_data(conm)

# %%
X_train, X_test, Y_train, Y_test = split(ex,label)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
# Out:
# シャッフルする:1 シャッフルしない:21
# testサイズを選んでください0.1

# %%
X_train.shape
# Out:
# (2934, 20, 1)

# %% [markdown]
# # LSTM系列

# %%
from tensorflow.keras.optimizers import RMSprop,Adam
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Bidirectional,LSTM,TimeDistributed
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
class Deep:
    
    def __init__(self,batchsize=32,unit=256,label_num=10,dropout=0.3,epochs=30):
        self.batchsize = batchsize
        self.unit = unit
        self.label_num = label_num
        self.dropout = dropout
        self.es = EarlyStopping(monitor='val_loss', patience=3, verbose=0, mode='auto')
        self.epochs = epochs
    
    def lstm(self,X_train):
        optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
        model = Sequential()
        model.add(LSTM(self.unit, input_shape = (X_train.shape[1], X_train.shape[2]), return_sequences = False))
        model.add(Dropout(self.dropout))
        model.add(Dense(self.label_num))
        model.add(Activation("softmax"))
        model.compile(loss = "categorical_crossentropy", optimizer = optimizer, metrics = ['accuracy'])
        model.summary()
        return model
    
    def learn(self,model,X_train, Y_train,validation_split):
        history = model.fit(X_train, Y_train, batch_size=self.batchsize, epochs=self.epochs,validation_split=validation_split)
        return history
    
    def plot_history(self,history):
    # model loss graph

        def plot_history_loss(fit):
            axL.plot(fit.history['loss'], label="loss for training")
            axL.plot(fit.history['val_loss'],label="loss for validation")
            axL.set_title('model loss')
            axL.set_xlabel('epoch')
            axL.set_ylabel('loss')
            axL.legend(loc='upper right')

        # model accuracy graph

        def plot_history_accuracy(fit):
            axR.plot(fit.history['accuracy'],
                     label="accuracy for training")
            axR.plot(fit.history['val_accuracy'],label="accuracy for validation")
            axR.set_title('model accuracy')
            axR.set_xlabel('epoch')
            axR.set_ylabel('accuracy')
            axR.legend(loc='lower right')

        ig, (axL, axR) = plt.subplots(ncols=2, figsize=(10, 5))
        plt.subplots_adjust(wspace=0.5)
        plot_history_loss(history)
        plot_history_accuracy(history)
        
    def model_save(self,model,model_name):
        model.save("{}.h5".format(model_name))
        model.save_weights("{}_weight.h5".format(model_name))
    
    def test(self,model,X_test,Y_test):
        evaluate_model(model,X_test,Y_test)

# %%
ls = Deep(epochs=100)

# %%
model = ls.lstm(X_train)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 256)               264192
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 266,762
# Trainable params: 266,762
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = ls.learn(model,X_train, Y_train,validation_split=0.2)
# Out:
# Epoch 1/100
# 74/74 [==============================] - 2s 26ms/step - loss: 2.2796 - accuracy: 0.1253 - val_loss: 2.2377 - val_accuracy: 0.1107
# Epoch 2/100
# 74/74 [==============================] - 1s 18ms/step - loss: 2.2157 - accuracy: 0.1589 - val_loss: 2.1764 - val_accuracy: 0.1567
# Epoch 3/100
# 74/74 [==============================] - 1s 18ms/step - loss: 2.1159 - accuracy: 0.1977 - val_loss: 2.0186 - val_accuracy: 0.2129
# Epoch 4/100
100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1152 - accuracy: 0.9625 - val_loss: 0.9181 - val_accuracy: 0.7325
# Epoch 55/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0749 - accuracy: 0.9706 - val_loss: 0.9223 - val_accuracy: 0.7513
# Epoch 56/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0534 - accuracy: 0.9842 - val_loss: 1.0457 - val_accuracy: 0.7376
# Epoch 57/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0577 - accuracy: 0.9753 - val_loss: 0.9500 - val_accuracy: 0.7598
# Epoch 58/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0375 - accuracy: 0.9872 - val_loss: 1.0110 - val_accuracy: 0.7445
# Epoch 59/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0477 - accuracy: 0.9864 - val_loss: 1.0138 - val_accuracy: 0.7445
# Epoch 60/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0587 - accuracy: 0.9787 - val_loss: 1.0075 - val_accuracy: 0.7564
# Epoch 61/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0349 - accuracy: 0.9859 - val_loss: 1.0033 - val_accuracy: 0.7496
# Epoch 62/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0369 - accuracy: 0.9885 - val_loss: 1.0255 - val_accuracy: 0.7564
# Epoch 63/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0648 - accuracy: 0.9749 - val_loss: 1.0683 - val_accuracy: 0.7462
# Epoch 64/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0428 - accuracy: 0.9851 - val_loss: 1.0909 - val_accuracy: 0.7394
# Epoch 65/100
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0594 - accuracy: 0.9808 - val_loss: 1.2507 - val_accuracy: 0.6746
# Epoch 66/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2242 - accuracy: 0.9220 - val_loss: 0.9516 - val_accuracy: 0.7359
# Epoch 67/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1769 - accuracy: 0.9357 - val_loss: 1.0710 - val_accuracy: 0.7274
# Epoch 68/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1343 - accuracy: 0.9523 - val_loss: 0.9847 - val_accuracy: 0.7462
# Epoch 69/100
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0699 - accuracy: 0.9761 - val_loss: 0.9163 - val_accuracy: 0.7547
# Epoch 70/100
# 34/74 [============>.................] - ETA: 0s - loss: 0.0534 - accuracy: 0.9816
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-165-cf5db0194424> in <module>
# ----> 1 history = ls.learn(model,X_train, Y_train,validation_split=0.2)
#
# <ipython-input-159-8db258d430bf> in learn(self, model, X_train, Y_train, validation_split)
#      21
#      22     def learn(self,model,X_train, Y_train,validation_split):
# ---> 23         history = model.fit(X_train, Y_train, batch_size=self.batchsize, epochs=self.epochs,validation_split=validation_split)
#      24         return history
#      25
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
ls.test(model,X_test,Y_test)
# Out:
# 19/19 [==============================] - 0s 7ms/step - loss: 0.9470 - accuracy: 0.7649
# loss: 0.9469770789146423 accuracy: 0.7649062871932983

# %%
pred = model.predict(X_test)

#予測データ
y_pred = np.argmax(pred,axis=1)

#正解データ
Y_acc = np.argmax(Y_test,axis=1)

class_names = data_col
cf_matrix = confusion_matrix(Y_acc, y_pred)
cd_df = pd.DataFrame(cf_matrix)

cd_df.columns=class_names
cd_df.index=class_names

plt.figure(figsize = (24,14))
sns.heatmap(cd_df.astype('float') / cd_df.sum(axis=1), annot=True, fmt='.2%' ,square = True,cmap='Reds')
plt.show()

# %%
ls.model_save(model,"model_本番1")

# %%
rr = load_model("model20_3.h5")
rr.load_weights("model_weight20_3.h5")

# %%
ls.test(rr,X_test,Y_test)
# Out:
# 11/11 [==============================] - 0s 5ms/step - loss: 2.5877 - accuracy: 0.4141
# loss: 2.5876753330230713 accuracy: 0.4141104221343994

# %%
X_test.shape
# Out:
# (652, 19, 1)
